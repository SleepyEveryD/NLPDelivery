# %% [markdown]
# # Who Wants to Be a PoliMillionaire? — NLP 2025/26 Group Assignment
#
# ## Group members
# - Jiaxin Yang — jiaxin.yang@mail.polimi.it
# - Runjie (Simone) Dai — runjie.dai@mail.polimi.it
#
# ## Video
# - Presentation video (≤5 min): https://youtu.be/Ub6XI_UnmH4?is=sGyjGIwOUgvoBZf9
#
# ## Statement on coding assistants
# We used a coding assistant (Claude Code) to help write, refactor and document parts of the implementation. The system design, the experiments, the prompt/RAG/routing strategies and all analysis are our own; the assignment was **not** handed to an LLM to complete.

# %% [markdown]
# <a href="https://colab.research.google.com/github/SleepyEveryD/NLPDelivery/blob/main/notebooks/04_adaptive_routing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/SleepyEveryD/NLPDelivery/blob/main/notebooks/04_adaptive_routing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 · Adaptive prompt routing — a small-LLM reasoning study
#
# **Research question:** for a small model (Qwen2.5-7B-Instruct), does routing each question to a prompt
# chosen for its *reasoning shape* beat forcing one universal prompt on everything? And the deeper one:
# **when does explicit reasoning help, and when does it hurt?**
#
# The motivating failure is real and on the leaderboard: the Maths run died at level 6 on a clock-chime
# *interval-counting* question — `cot_v2`'s hard "≤3 steps" brevity cap made the model **guess before it
# had counted**. That same cap is what keeps verbose stats questions from timing out. One prompt cannot
# serve both regimes — which is exactly the hypothesis this experiment tests.
#
# We isolate ONE variable — the **prompt strategy** — and compare four conditions over a labelled
# 8-category reasoning set:
#
# | condition | prompt |
# |---|---|
# | **A_universal** | one universal prompt (production `few_shot_v1`) |
# | **B_generic_cot** | always plain "think step by step" |
# | **C_structured** | always structured enumeration |
# | **D_adaptive** | `ReasoningRouter` picks per question |
#
# No retrieval, no calculator here — *only* the prompt changes between conditions, so the effect we
# measure is the prompt's alone.

# %% [markdown]
# ## 1 · Setup — clone/pull the repo, put `src` on the path
# Runs on Colab (clones) **or** locally (uses the repo you are already in).

# %%
import os, sys

# Stand in a directory that definitely EXISTS before anything else. A prior `!rm -rf /content/NLP`
# can delete the notebook's current working directory, after which every shell command fails with
# "Unable to read current working directory". Recover from that here.
SAFE = '/content' if os.path.isdir('/content') else os.path.expanduser('~')
try:
    os.getcwd()
except OSError:
    os.chdir(SAFE)

# Colab: clone/refresh the *main* branch into /content/NLP.
# Local: use the repo this notebook already sits in.
REPO_URL = 'https://github.com/SleepyEveryD/NLPDelivery.git'
BRANCH = 'main'
if os.path.isdir('/content'):
    os.chdir('/content')                       # clone from OUTSIDE the repo dir, never from within it.
    REPO_ROOT = '/content/NLP'
    if not os.path.exists(REPO_ROOT):
        # !git clone -b {BRANCH} {REPO_URL} {REPO_ROOT}
    else:
        # Existing checkout: ensure we are on main and current.
        # !cd {REPO_ROOT} && git fetch -q origin {BRANCH} && git checkout -q {BRANCH} && git pull -q origin {BRANCH}
else:
    REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..')) if os.path.basename(os.getcwd()) == 'notebooks' else os.getcwd()

SRC = os.path.join(REPO_ROOT, 'src')
if SRC not in sys.path:
    sys.path.insert(0, SRC)
os.chdir(REPO_ROOT)
print('Repo root:', REPO_ROOT)
print('On sys.path:', SRC)
assert os.path.exists('data/reasoning_eval.jsonl'), 'Missing data/reasoning_eval.jsonl -- on the main branch, are you?'

# --- Persistent model cache on Google Drive ------------------------------------------------------
# The Qwen 7B weights (~15GB) download ONCE to Drive, then every notebook/session reuses them --
# no repeat downloads. Set BEFORE transformers is imported, this must be. BEST-EFFORT: outside Colab,
# or if the Drive prompt you decline, fall back to the ephemeral cache (re-downloads, but never errors).
try:
    from google.colab import drive as _drive
    if not os.path.isdir('/content/gdrive/MyDrive'):
        _drive.mount('/content/gdrive')
    _hf = '/content/gdrive/MyDrive/hf_cache'
    os.makedirs(_hf, exist_ok=True)
    os.environ['HF_HOME'] = _hf
    print('HF cache ->', _hf, '(model downloads once, reused after)')
except Exception as _e:
    print(f'Drive cache off ({type(_e).__name__}) -- ephemeral cache, the model re-downloads each session.')

# %%
# Install the inference stack so the REAL Qwen 4-bit load works.
# `-U` + bitsandbytes>=0.46.1 is MANDATORY: Colab preinstalls a stale bitsandbytes (<0.46.1) and a bare
# pin leaves it be, so the 4-bit loader ImportErrors and the experiment silently falls back to the
# SIMULATED fixture (not the model). pandas/requests pinned to Colab's own versions -- bare names break
# google-colab / cudf / gradio. Skip this cell ONLY if you intend to run the fixture.
# !pip install -q -U 'transformers>=4.45.0' 'accelerate>=0.34.0' 'bitsandbytes>=0.46.1' sentencepiece einops pyyaml 'pandas==2.2.2' matplotlib 'requests==2.32.4'
print('Dependencies installed. IMPORTANT: now Runtime > Restart session, then Run all again --')
print('bitsandbytes must be re-imported fresh, or the 4-bit loader keeps the old version.')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 121.9 MB/s eta 0:00:00
# Dependencies installed. IMPORTANT: now Runtime > Restart session, then Run all again --
# bitsandbytes must be re-imported fresh, or the 4-bit loader keeps the old version.

# %% [markdown]
# ## 2 · Load the labelled reasoning set
# 40 MCQs across 8 categories, each with a hand-verified gold answer **and** a gold reasoning-category label (the truth the router is scored against). The clock-chime question that broke the live Maths run is `ic-001`.

# %%
from experiments.adaptive_routing import load_reasoning_eval

questions, categories = load_reasoning_eval('data/reasoning_eval.jsonl')
print(f'{len(questions)} questions; categories:')
from collections import Counter
for cat, n in sorted(Counter(categories.values()).items()):
    print(f'  {cat:<22} {n}')
print('\nThe motivating failure, ic-001:')
print(' ', next(q.text for q in questions if q.qid == 'ic-001')[:140], '...')
# Out:
# 48 questions; categories:
#   arithmetic             5
#   commonsense            5
#   discrete_enumeration   5
#   factual_qa             5
#   interval_counting      5
#   logical_reasoning      13
#   multi_hop              5
#   temporal_reasoning     5
#
# The motivating failure, ic-001:
#   If a clock chimes every hour the same number of times as the hour it is (e.g., at 3 P.M. it chimes 3 times) and once for every 15-minute inc ...

# %% [markdown]
# ## 3 · Pick the engine
#
# **Real run (Colab GPU):** `TransformersEngine` loads Qwen2.5-7B 4-bit — the numbers are real.
#
# **Local / no-GPU:** `SimulatedReasoningEngine` — a **deterministic fixture, NOT a model**. Its
# correctness comes from a hand-set skill table that *encodes the hypothesis*, so it validates the
# **harness** (routing, logging, metrics, figures) end-to-end. It does **not** produce real findings.

# %%
USE_REAL_MODEL = True   # set False to force the simulated fixture

engine = None
if USE_REAL_MODEL:
    try:
        from inference.engine import TransformersEngine
        from config import RunConfig
        cfg = RunConfig.from_yaml('configs/live.yaml')
        engine = TransformersEngine(cfg.model.name, cfg.model.quantization, cfg.model.dtype)
        engine.warmup()
        print('REAL engine loaded:', engine.name)
    except Exception as e:
        print(f'Real engine unavailable ({type(e).__name__}: {e})')
        print('-> falling back to the SIMULATED fixture.')
        engine = None

if engine is None:
    from inference.engine import SimulatedReasoningEngine
    engine = SimulatedReasoningEngine(questions, categories)
    print('\n' + '!' * 72)
    print('!! SIMULATED FIXTURE ENGINE -- validates the HARNESS, not the model.   !!')
    print('!! Real findings need USE_REAL_MODEL=True on a Colab GPU runtime.      !!')
    print('!' * 72)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# REAL engine loaded: Qwen/Qwen2.5-7B-Instruct

# %% [markdown]
# ## 4 · Run the experiment — 4 conditions × 40 questions
# Writes one `experiments/adaptive_routing/records.jsonl` (strategy chosen, router verdict, correctness, latency, tokens, reasoning length, raw output).

# %%
from experiments.adaptive_routing import AdaptiveRoutingExperiment

# max_new_tokens=512 (vs the 256 default): the game allows 130s/question, so a longer cap is free and
# fixes the no_answer_parsed truncations where verbose chains never reached the 'Answer:' line.
exp = AdaptiveRoutingExperiment(engine, max_new_tokens=512)
records_path = exp.run(questions, categories, verbose=True)
records_path
# Out:
# === Condition A_universal: Single universal prompt (production few_shot_v1) ===
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#   [1/192] ic-001  A_universal    strat=few_shot_v1                 -> B (gold C) [  X]
#   [2/192] ic-002  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [3/192] ic-003  A_universal    strat=few_shot_v1                 -> C (gold B) [  X]
#   [4/192] ic-004  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [5/192] ic-005  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [6/192] tr-001  A_universal    strat=few_shot_v1                 -> A (gold B) [  X]
#   [7/192] tr-002  A_universal    strat=few_shot_v1                 -> C (gold B) [  X]
#   [8/192] tr-003  A_universal    strat=few_shot_v1                 -> A (gold A) [ok ]
#   [9/192] tr-004  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [10/192] tr-005  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [11/192] de-001  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [12/192] de-002  A_universal    strat=few_shot_v1                 -> A (gold B) [  X]
#   [13/192] de-003  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [14/192] de-004  A_universal    strat=few_shot_v1                 -> D (gold B) [  X]
#   [15/192] de-005  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [16/192] ar-001  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [17/192] ar-002  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [18/192] ar-003  A_universal    strat=few_shot_v1                 -> B (gold A) [  X]
#   [19/192] ar-004  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [20/192] ar-005  A_universal    strat=few_shot_v1                 -> A (gold B) [  X]
#   [21/192] fa-001  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [22/192] fa-002  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [23/192] fa-003  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [24/192] fa-004  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [25/192] fa-005  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [26/192] cs-001  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [27/192] cs-002  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [28/192] cs-003  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [29/192] cs-004  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [30/192] cs-005  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [31/192] lr-001  A_universal    strat=few_shot_v1                 -> B (gold D) [  X]
#   [32/192] lr-002  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [33/192] lr-003  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [34/192] lr-004  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [35/192] lr-005  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [36/192] mh-001  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [37/192] mh-002  A_universal    strat=few_shot_v1                 -> B (gold C) [  X]
#   [38/192] mh-003  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [39/192] mh-004  A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [40/192] mh-005  A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [41/192] log-ind-001 A_universal    strat=few_shot_v1                 -> C (gold D) [  X]
#   [42/192] log-ind-002 A_universal    strat=few_shot_v1                 -> A (gold A) [ok ]
#   [43/192] log-ind-003 A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#   [44/192] log-ind-004 A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [45/192] log-ind-005 A_universal    strat=few_shot_v1                 -> D (gold D) [ok ]
#   [46/192] log-stat-001 A_universal    strat=few_shot_v1                 -> B (gold B) [ok ]
#   [47/192] log-stat-002 A_universal    strat=few_shot_v1                 -> A (gold A) [ok ]
#   [48/192] log-stat-003 A_universal    strat=few_shot_v1                 -> C (gold C) [ok ]
#
# === Condition B_generic_cot: Always generic chain-of-thought ===
#   [49/192] ic-001  B_generic_cot  strat=generic_cot                 -> A (gold C) [  X]
#   [50/192] ic-002  B_generic_cot  strat=generic_cot                 -> A (gold B) [  X]
#   [51/192] ic-003  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [52/192] ic-004  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [53/192] ic-005  B_generic_cot  strat=generic_cot                 -> A (gold B) [  X]
#   [54/192] tr-001  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [55/192] tr-002  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [56/192] tr-003  B_generic_cot  strat=generic_cot                 -> A (gold A) [ok ]
#   [57/192] tr-004  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [58/192] tr-005  B_generic_cot  strat=generic_cot                 -> C (gold B) [  X]
#   [59/192] de-001  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [60/192] de-002  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [61/192] de-003  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [62/192] de-004  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [63/192] de-005  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [64/192] ar-001  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [65/192] ar-002  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [66/192] ar-003  B_generic_cot  strat=generic_cot                 -> A (gold A) [ok ]
#   [67/192] ar-004  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [68/192] ar-005  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [69/192] fa-001  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [70/192] fa-002  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [71/192] fa-003  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [72/192] fa-004  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [73/192] fa-005  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [74/192] cs-001  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [75/192] cs-002  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [76/192] cs-003  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [77/192] cs-004  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [78/192] cs-005  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [79/192] lr-001  B_generic_cot  strat=generic_cot                 -> B (gold D) [  X]
#   [80/192] lr-002  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [81/192] lr-003  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [82/192] lr-004  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [83/192] lr-005  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [84/192] mh-001  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [85/192] mh-002  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [86/192] mh-003  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [87/192] mh-004  B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [88/192] mh-005  B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [89/192] log-ind-001 B_generic_cot  strat=generic_cot                 -> C (gold D) [  X]
#   [90/192] log-ind-002 B_generic_cot  strat=generic_cot                 -> A (gold A) [ok ]
#   [91/192] log-ind-003 B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#   [92/192] log-ind-004 B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [93/192] log-ind-005 B_generic_cot  strat=generic_cot                 -> D (gold D) [ok ]
#   [94/192] log-stat-001 B_generic_cot  strat=generic_cot                 -> B (gold B) [ok ]
#   [95/192] log-stat-002 B_generic_cot  strat=generic_cot                 -> A (gold A) [ok ]
#   [96/192] log-stat-003 B_generic_cot  strat=generic_cot                 -> C (gold C) [ok ]
#
# === Condition C_structured: Always structured enumeration ===
#   [97/192] ic-001  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [98/192] ic-002  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [99/192] ic-003  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [100/192] ic-004  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [101/192] ic-005  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [102/192] tr-001  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [103/192] tr-002  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [104/192] tr-003  C_structured   strat=structured_enumeration_cot  -> A (gold A) [ok ]
#   [105/192] tr-004  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [106/192] tr-005  C_structured   strat=structured_enumeration_cot  -> D (gold B) [  X]
#   [107/192] de-001  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [108/192] de-002  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [109/192] de-003  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [110/192] de-004  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [111/192] de-005  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [112/192] ar-001  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [113/192] ar-002  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [114/192] ar-003  C_structured   strat=structured_enumeration_cot  -> A (gold A) [ok ]
#   [115/192] ar-004  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [116/192] ar-005  C_structured   strat=structured_enumeration_cot  -> A (gold B) [  X]
#   [117/192] fa-001  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [118/192] fa-002  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [119/192] fa-003  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [120/192] fa-004  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [121/192] fa-005  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [122/192] cs-001  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [123/192] cs-002  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [124/192] cs-003  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [125/192] cs-004  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [126/192] cs-005  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [127/192] lr-001  C_structured   strat=structured_enumeration_cot  -> D (gold D) [ok ]
#   [128/192] lr-002  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [129/192] lr-003  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [130/192] lr-004  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [131/192] lr-005  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [132/192] mh-001  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [133/192] mh-002  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [134/192] mh-003  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [135/192] mh-004  C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [136/192] mh-005  C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [137/192] log-ind-001 C_structured   strat=structured_enumeration_cot  -> C (gold D) [  X]
#   [138/192] log-ind-002 C_structured   strat=structured_enumeration_cot  -> A (gold A) [ok ]
#   [139/192] log-ind-003 C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [140/192] log-ind-004 C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [141/192] log-ind-005 C_structured   strat=structured_enumeration_cot  -> D (gold D) [ok ]
#   [142/192] log-stat-001 C_structured   strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [143/192] log-stat-002 C_structured   strat=structured_enumeration_cot  -> A (gold A) [ok ]
#   [144/192] log-stat-003 C_structured   strat=structured_enumeration_cot  -> C (gold C) [ok ]
#
# === Condition D_adaptive: Adaptive prompt routing (ReasoningRouter) ===
#   [145/192] ic-001  D_adaptive     strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [146/192] ic-002  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [147/192] ic-003  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [148/192] ic-004  D_adaptive     strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [149/192] ic-005  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [150/192] tr-001  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [151/192] tr-002  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [152/192] tr-003  D_adaptive     strat=structured_enumeration_cot  -> A (gold A) [ok ]
#   [153/192] tr-004  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [154/192] tr-005  D_adaptive     strat=structured_enumeration_cot  -> D (gold B) [  X]
#   [155/192] de-001  D_adaptive     strat=structured_enumeration_cot  -> C (gold C) [ok ]
#   [156/192] de-002  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [157/192] de-003  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [158/192] de-004  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [159/192] de-005  D_adaptive     strat=structured_enumeration_cot  -> B (gold B) [ok ]
#   [160/192] ar-001  D_adaptive     strat=generic_cot                 -> C (gold C) [ok ]
#   [161/192] ar-002  D_adaptive     strat=generic_cot                 -> B (gold B) [ok ]
#   [162/192] ar-003  D_adaptive     strat=generic_cot                 -> A (gold A) [ok ]
#   [163/192] ar-004  D_adaptive     strat=generic_cot                 -> B (gold B) [ok ]
#   [164/192] ar-005  D_adaptive     strat=generic_cot                 -> B (gold B) [ok ]
#   [165/192] fa-001  D_adaptive     strat=direct_answer               -> C (gold C) [ok ]
#   [166/192] fa-002  D_adaptive     strat=direct_answer               -> C (gold C) [ok ]
#   [167/192] fa-003  D_adaptive     strat=direct_answer               -> B (gold B) [ok ]
#   [168/192] fa-004  D_adaptive     strat=direct_answer               -> C (gold C) [ok ]
#   [169/192] fa-005  D_adaptive     strat=direct_answer               -> C (gold C) [ok ]
#   [170/192] cs-001  D_adaptive     strat=direct_answer               -> B (gold B) [ok ]
#   [171/192] cs-002  D_adaptive     strat=direct_answer               -> C (gold C) [ok ]
#   [172/192] cs-003  D_adaptive     strat=direct_answer               -> B (gold B) [ok ]
#   [173/192] cs-004  D_adaptive     strat=direct_answer               -> B (gold B) [ok ]
#   [174/192] cs-005  D_adaptive     strat=direct_answer               -> B (gold B) [ok ]
#   [175/192] lr-001  D_adaptive     strat=checklist_cot               -> B (gold D) [  X]
#   [176/192] lr-002  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [177/192] lr-003  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [178/192] lr-004  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [179/192] lr-005  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [180/192] mh-001  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [181/192] mh-002  D_adaptive     strat=checklist_cot               -> C (gold C) [ok ]
#   [182/192] mh-003  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [183/192] mh-004  D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [184/192] mh-005  D_adaptive     strat=checklist_cot               -> C (gold C) [ok ]
#   [185/192] log-ind-001 D_adaptive     strat=checklist_cot               -> A (gold D) [  X]
#   [186/192] log-ind-002 D_adaptive     strat=checklist_cot               -> A (gold A) [ok ]
#   [187/192] log-ind-003 D_adaptive     strat=checklist_cot               -> B (gold C) [  X]
#   [188/192] log-ind-004 D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [189/192] log-ind-005 D_adaptive     strat=checklist_cot               -> D (gold D) [ok ]
#   [190/192] log-stat-001 D_adaptive     strat=checklist_cot               -> B (gold B) [ok ]
#   [191/192] log-stat-002 D_adaptive     strat=checklist_cot               -> A (gold A) [ok ]
#   [192/192] log-stat-003 D_adaptive     strat=generic_cot                 -> C (gold C) [ok ]
#
# Wrote 192 records -> experiments/adaptive_routing/records.jsonl
# 'experiments/adaptive_routing/records.jsonl'

# %% [markdown]
# ### 🔬 Core implementation: adaptive routing (category → strategy) + a deterministic Maths solver
#
# **(a) Reasoning-shape routing** (`src/classify/reasoning_router.py`) -- first classify the question into one of 8 reasoning shapes, then pick the prompt from a policy table. The whole thing is the 3 lines of `route()` plus one policy table:
#
# ```python
# def route(self, question: Question) -> tuple[ReasoningSignal, str]:
#     signal   = self.classifier.classify(question)                 # 8 classes: arithmetic / temporal /
#     strategy = self.policy.get(signal.category, self.fallback)    #   interval_counting / discrete_enum /
#     return signal, strategy                                       #   factual_qa / commonsense / logical / multi_hop
#
# DEFAULT_ROUTING_POLICY = {
#     # recall/commonsense: an explicit chain hurts (hallucinated justification, drift) -> answer directly
#     FACTUAL_QA: "direct_answer",  COMMONSENSE: "direct_answer",
#     ARITHMETIC: "generic_cot",                                    # pure computation: take steps but don't over-enumerate
#     TEMPORAL_REASONING:   "structured_enumeration_cot",          # must list events/cases in order before counting ->
#     INTERVAL_COUNTING:    "structured_enumeration_cot",          #   enumerate first (the bell-chime 0.4->1.0 fix)
#     DISCRETE_ENUMERATION: "structured_enumeration_cot",
#     LOGICAL_REASONING: "checklist_cot",  MULTI_HOP: "checklist_cot",  # multi-clause/validity: a per-item checklist
# }
# ```
#
# `RoutingPromptBuilder` is a duck-type of `PromptBuilder`: the pipeline still only calls `.build()` and reads `.strategy`, but the strategy **varies per question** (EvalRecord logs which prompt actually ran). Live Maths uses a **conservative policy**: only the counting/temporal shapes with offline evidence are re-routed, and everything else stays on the battle-tested `cot_v2`, minimizing regression risk.
#
# **(b) Deterministic Maths solver** (`src/tools/math_solvers.py`) -- runs **before** the LLM; on a hit (single option, correct by construction) it answers directly and skips the model; otherwise it abstains (returns None) and the LLM path is completely unaffected -- it can only **add correct answers**, never override the model:
#
# ```python
# _SOLVERS = (_solve_finite_field_roots, _solve_ring_characteristic, _solve_gcd,
#             _solve_common_divisor_count, _solve_subspace_intersection_dim, _solve_sum_product,
#             _solve_reflection_yx, _solve_triangle_sides, _solve_percentage_increase,
#             _solve_operator_placement, _solve_weekday, _solve_parallelogram_angle, _solve_arith_expression)
#
# def solve_maths(question: Question):
#     if not question.options: return None                 # MCQ only
#     q = _norm(question)                                   # normalize unicode minus/dash signs first
#     for fn in _SOLVERS:                                   # each type-specific solver in turn
#         try: res = fn(q)
#         except Exception: res = None                      # crash-safe: an exception counts as an abstention
#         if res is not None: return res                    # first deterministic hit wins
#     return None                                           # all abstain -> hand off to the LLM
# ```
#
# Sections 5-11 below are the full offline experiment: 4 conditions × 40 questions, with a category×condition heatmap, latency-accuracy trade-off, routing-annotation correctness, and a failure taxonomy.

# %% [markdown]
# ## 5 · Headline — does adaptive (D) beat the rest, and at what cost?

# %%
import pandas as pd
from experiments import analysis
pd.set_option('display.width', 170); pd.set_option('display.max_columns', 20)

df = analysis.load_records(records_path)
comp = analysis.strategy_comparison_table(df)
comp.round(3)
# Out:
#        condition  accuracy   n  mean_latency_s  p95_latency_s  mean_tokens_out  mean_reasoning_lines
# 0    A_universal     0.771  48           1.452          1.662            2.000                 1.000
# 1  B_generic_cot     0.875  48          19.597         37.243          224.333                10.854
# 2   C_structured     0.938  48          13.727         24.616          147.500                11.833
# 3     D_adaptive     0.917  48          16.835         35.758          186.583                11.875

# %%
from IPython.display import Image, display
analysis.plot_condition_accuracy_bars(df)
display(Image('experiments/adaptive_routing/fig_condition_accuracy.png'))

# %% [markdown]
# ## 6 · WHERE each prompt helps or hurts — category × condition heatmap
# The whole hypothesis in one figure: a prompt that is green on one row can be red on another.

# %%
analysis.plot_category_heatmap(df)
display(Image('experiments/adaptive_routing/fig_category_heatmap.png'))
analysis.category_accuracy_matrix(df).round(2)
# Out:
# condition             A_universal  B_generic_cot  C_structured  D_adaptive
# true_category
# arithmetic                   0.60           1.00          0.80        1.00
# temporal_reasoning           0.60           0.80          0.80        0.80
# interval_counting            0.60           0.40          1.00        1.00
# discrete_enumeration         0.60           1.00          1.00        1.00
# factual_qa                   1.00           1.00          1.00        1.00
# commonsense                  1.00           1.00          1.00        1.00
# logical_reasoning            0.85           0.85          0.92        0.77
# multi_hop                    0.80           1.00          1.00        1.00

# %% [markdown]
# ## 7 · The cost of reasoning — latency vs accuracy

# %%
analysis.plot_latency_accuracy(df)
display(Image('experiments/adaptive_routing/fig_latency_accuracy.png'))

# %% [markdown]
# ## 8 · The oracle the router chases — best fixed strategy per category
# If the per-category best fixed strategy and the adaptive arm agree, the router is doing its job.

# %%
analysis.best_strategy_per_category(df)
# Out:
#                category               best_strategy  best_accuracy  adaptive_accuracy
# 0            arithmetic                 generic_cot       1.000000           1.000000
# 1    temporal_reasoning                 generic_cot       0.800000           0.800000
# 2     interval_counting  structured_enumeration_cot       1.000000           1.000000
# 3  discrete_enumeration                 generic_cot       1.000000           1.000000
# 4            factual_qa               direct_answer       1.000000           1.000000
# 5           commonsense               direct_answer       1.000000           1.000000
# 6     logical_reasoning  structured_enumeration_cot       0.923077           0.769231
# 7             multi_hop               checklist_cot       1.000000           1.000000

# %% [markdown]
# ## 9 · Did the classifier label the reasoning shape correctly?
# Routing accuracy + a confusion table (true category vs the category the classifier inferred).

# %%
rep = analysis.routing_report(df)
print('overall routing accuracy:', round(rep['overall_routing_accuracy'], 3))
rep['confusion']
# Out:
# overall routing accuracy: 0.979
# routed_category       arithmetic  temporal_reasoning  interval_counting  discrete_enumeration  factual_qa  commonsense  logical_reasoning  multi_hop
# true_category
# arithmetic                     5                   0                  0                     0           0            0                  0          0
# temporal_reasoning             0                   5                  0                     0           0            0                  0          0
# interval_counting              0                   0                  5                     0           0            0                  0          0
# discrete_enumeration           0                   0                  0                     5           0            0                  0          0
# factual_qa                     0                   0                  0                     0           5            0                  0          0
# commonsense                    0                   0                  0                     0           0            5                  0          0
# logical_reasoning              1                   0                  0                     0           0            0                 12          0
# multi_hop                      0                   0                  0                     0           0            0                  0          5

# %% [markdown]
# ## 10 · Failure taxonomy — *why* each prompt got things wrong
# Heuristic labels from the raw output: overthinking (recall Q over-reasoned), boundary_error (counting off-by-one), skipped_case (never enumerated), arithmetic_drift, no_answer_parsed, hallucinated/other.

# %%
analysis.failure_taxonomy(df)
# Out:
# failure_mode   boundary_error  hallucinated/other  no_answer_parsed  skipped_case
# condition
# A_universal                 0                   0                 0            11
# B_generic_cot               3                   2                 1             0
# C_structured                1                   1                 1             0
# D_adaptive                  1                   2                 1             0

# %% [markdown]
# ## 11 · Findings & recommendation
#
# The full write-up lives in **`experiments/adaptive_routing_findings.md`** (publication-style section).
#
# **Headline (to confirm on the real Colab run):**
# - **Adaptive routing (D) should beat every single fixed prompt (A/B/C)** — because no one prompt is
#   best across all categories, and D picks the per-category winner.
# - **Structured enumeration is the cure for interval-counting / temporal questions** (the clock-chime
#   family) but **hurts factual recall** (overthinking) — never make it the universal default.
# - **Direct answering wins on factual_qa / commonsense**; **checklists win on logic / multi-hop**.
# - The router's weakest spot is **multi_hop** (it surface-overlaps with factual recall).
#
# **Recommendation for the live game:** in `notebooks/03_live_play.ipynb`, give the **Maths** pipeline a
# per-question router that sends interval-counting / temporal / enumeration questions to
# `structured_enumeration_cot` and leaves concept/stats questions on the current chain — exactly the
# regime split `cot_v2`'s single brevity cap conflated.

# %% [markdown]
# ## 12 · Focused A/B — the level-11 induction death (logic questions)
#
# The live Maths run got past the counting deaths (structured routing worked) and died at **level 11** on
# a strong-induction question (`log-ind-001`, the real qid 6737): `cot_v2` wrote a 24-token wrong one-liner
# ("n0 is a counterexample, so all higher values are also counterexamples") — its **brevity cap gagged the
# reasoning**, the same root cause as the clock-chime death.
#
# This section pits four prompts over the **logic questions** (the original `lr-*`, five induction /
# contrapositive `log-ind-*`, and three "which-of-the-following-is-true" stats look-alikes `log-stat-*`):
#
# | arm | prompt |
# |---|---|
# | `cot_v2` | the current Maths fallback (≤3-step brevity cap) |
# | `generic_cot` | step-by-step, **no** cap |
# | `checklist_cot` | per-option verification checklist |
# | `checklist_sc5` | checklist + **self-consistency** vote (n=5) — affordable under the 130s budget |
#
# **Decision rule:** adopt the arm that fixes the induction (`log-ind-*`) questions **without** regressing
# the stats (`log-stat-*`) ones (those currently win on `cot_v2`).

# %%
from experiments.adaptive_routing import AdaptiveRoutingExperiment, LOGIC_FOCUS_CONDITIONS

# All logic questions (lr-* + log-ind-* + log-stat-*). Same engine as above (real Qwen on Colab).
logic_qs = [q for q in questions if categories[q.qid] == 'logical_reasoning']
print(f'{len(logic_qs)} logic questions:', [q.qid for q in logic_qs])

logic_exp = AdaptiveRoutingExperiment(
    engine, conditions=LOGIC_FOCUS_CONDITIONS,
    out_dir='experiments/adaptive_routing_logic', max_new_tokens=512,
)
logic_path = logic_exp.run(logic_qs, categories, verbose=True)
logic_path
# Out:
# 13 logic questions: ['lr-001', 'lr-002', 'lr-003', 'lr-004', 'lr-005', 'log-ind-001', 'log-ind-002', 'log-ind-003', 'log-ind-004', 'log-ind-005', 'log-stat-001', 'log-stat-002', 'log-stat-003']
#
# === Condition cot_v2: The current Maths fallback (=3-step brevity cap) ===
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#   [1/52] lr-001  cot_v2         strat=cot_v2                      -> B (gold D) [  X]
#   [2/52] lr-002  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [3/52] lr-003  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [4/52] lr-004  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [5/52] lr-005  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [6/52] log-ind-001 cot_v2         strat=cot_v2                      -> C (gold D) [  X]
#   [7/52] log-ind-002 cot_v2         strat=cot_v2                      -> A (gold A) [ok ]
#   [8/52] log-ind-003 cot_v2         strat=cot_v2                      -> C (gold C) [ok ]
#   [9/52] log-ind-004 cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [10/52] log-ind-005 cot_v2         strat=cot_v2                      -> D (gold D) [ok ]
#   [11/52] log-stat-001 cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [12/52] log-stat-002 cot_v2         strat=cot_v2                      -> A (gold A) [ok ]
#   [13/52] log-stat-003 cot_v2         strat=cot_v2                      -> C (gold C) [ok ]
#
# === Condition generic_cot: Step-by-step, NO brevity cap ===
#   [14/52] lr-001  generic_cot    strat=generic_cot                 -> B (gold D) [  X]
#   [15/52] lr-002  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [16/52] lr-003  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [17/52] lr-004  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [18/52] lr-005  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [19/52] log-ind-001 generic_cot    strat=generic_cot                 -> C (gold D) [  X]
#   [20/52] log-ind-002 generic_cot    strat=generic_cot                 -> A (gold A) [ok ]
#   [21/52] log-ind-003 generic_cot    strat=generic_cot                 -> C (gold C) [ok ]
#   [22/52] log-ind-004 generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [23/52] log-ind-005 generic_cot    strat=generic_cot                 -> D (gold D) [ok ]
#   [24/52] log-stat-001 generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [25/52] log-stat-002 generic_cot    strat=generic_cot                 -> A (gold A) [ok ]
#   [26/52] log-stat-003 generic_cot    strat=generic_cot                 -> C (gold C) [ok ]
#
# === Condition checklist_cot: Per-option verification checklist ===
#   [27/52] lr-001  checklist_cot  strat=checklist_cot               -> B (gold D) [  X]
#   [28/52] lr-002  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [29/52] lr-003  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [30/52] lr-004  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [31/52] lr-005  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [32/52] log-ind-001 checklist_cot  strat=checklist_cot               -> A (gold D) [  X]
#   [33/52] log-ind-002 checklist_cot  strat=checklist_cot               -> A (gold A) [ok ]
#   [34/52] log-ind-003 checklist_cot  strat=checklist_cot               -> B (gold C) [  X]
#   [35/52] log-ind-004 checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [36/52] log-ind-005 checklist_cot  strat=checklist_cot               -> D (gold D) [ok ]
#   [37/52] log-stat-001 checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [38/52] log-stat-002 checklist_cot  strat=checklist_cot               -> A (gold A) [ok ]
#   [39/52] log-stat-003 checklist_cot  strat=checklist_cot               -> C (gold C) [ok ]
#
# === Condition checklist_sc5: Checklist + self-consistency vote (n=5) ===
#   [40/52] lr-001  checklist_sc5  strat=checklist_cot               -> B (gold D) [  X]
#   [41/52] lr-002  checklist_sc5  strat=checklist_cot               -> B (gold B) [ok ]
#   [42/52] lr-003  checklist_sc5  strat=checklist_cot               -> B (gold B) [ok ]
#   [43/52] lr-004  checklist_sc5  strat=checklist_cot               -> D (gold B) [  X]
#   [44/52] lr-005  checklist_sc5  strat=checklist_cot               -> B (gold B) [ok ]
#   [45/52] log-ind-001 checklist_sc5  strat=checklist_cot               -> C (gold D) [  X]
#   [46/52] log-ind-002 checklist_sc5  strat=checklist_cot               -> A (gold A) [ok ]
#   [47/52] log-ind-003 checklist_sc5  strat=checklist_cot               -> C (gold C) [ok ]
#   [48/52] log-ind-004 checklist_sc5  strat=checklist_cot               -> B (gold B) [ok ]
#   [49/52] log-ind-005 checklist_sc5  strat=checklist_cot               -> D (gold D) [ok ]
#   [50/52] log-stat-001 checklist_sc5  strat=checklist_cot               -> B (gold B) [ok ]
#   [51/52] log-stat-002 checklist_sc5  strat=checklist_cot               -> A (gold A) [ok ]
#   [52/52] log-stat-003 checklist_sc5  strat=checklist_cot               -> C (gold C) [ok ]
#
# Wrote 52 records -> experiments/adaptive_routing_logic/records.jsonl
# 'experiments/adaptive_routing_logic/records.jsonl'

# %% [markdown]
# ### 12.1 · Per-condition accuracy on logic questions

# %%
import pandas as pd
ldf = analysis.load_records(logic_path)
order = [c.name for c in LOGIC_FOCUS_CONDITIONS]
ldf.groupby('condition')['correct'].agg(accuracy='mean', n='count').reindex(order)
# Out:
#                accuracy   n
# condition
# cot_v2         0.846154  13
# generic_cot    0.846154  13
# checklist_cot  0.769231  13
# checklist_sc5  0.769231  13

# %% [markdown]
# ### 12.2 · Per-question correctness (the decision table)
# `1.0` = correct. Look at the `log-ind-*` rows (does a prompt fix the induction death?) vs the `log-stat-*` rows (does it regress the stats look-alikes?).

# %%
piv = ldf.pivot_table(index='qid', columns='condition', values='correct').reindex(columns=order)
# order rows: induction first, then stats, then the original lr-*
row_order = [q.qid for q in logic_qs]
piv = piv.reindex(row_order)
piv
# Out:
# condition     cot_v2  generic_cot  checklist_cot  checklist_sc5
# qid
# lr-001           0.0          0.0            0.0            0.0
# lr-002           1.0          1.0            1.0            1.0
# lr-003           1.0          1.0            1.0            1.0
# lr-004           1.0          1.0            1.0            0.0
# lr-005           1.0          1.0            1.0            1.0
# log-ind-001      0.0          0.0            0.0            0.0
# log-ind-002      1.0          1.0            1.0            1.0
# log-ind-003      1.0          1.0            0.0            1.0
# log-ind-004      1.0          1.0            1.0            1.0
# log-ind-005      1.0          1.0            1.0            1.0
# log-stat-001     1.0          1.0            1.0            1.0
# log-stat-002     1.0          1.0            1.0            1.0
# log-stat-003     1.0          1.0            1.0            1.0

# %% [markdown]
# ### 12.3 · Read-out & decision
#
# - If `checklist_cot` (or `checklist_sc5`) flips `log-ind-001` (qid 6737) and the other `log-ind-*` to
#   correct **while keeping every `log-stat-*` correct**, then change the live Maths policy so
#   `logical_reasoning -> checklist_cot` (edit `MATHS_LIVE_POLICY` in `src/classify/reasoning_router.py`).
# - If checklist **regresses** the stats questions, keep `cot_v2` for them and consider self-consistency
#   on `cot_v2` instead, or a finer classifier split (induction vs stats-conclusion).
# - The classifier already routes induction questions to `logical_reasoning` (fixed this turn — they used
#   to leak to `arithmetic` via the incidental `+1`), so whatever wins here can actually be targeted live.

# %% [markdown]
# ## 13 · Probe — does explicit logical-DIRECTION prompting break the induction ceiling?
#
# §5c showed the level-11 death (qid 6737) survives `cot_v2`, `generic_cot`, `checklist_cot` AND a
# 5-vote self-consistency: a **systematic directional misconception** (the model thinks falsity propagates
# *forward*). This probe adds **`implication_cot`** — the one prompt that scaffolds the direction: write
# `P -> Q`, write the valid contrapositive `not Q -> not P`, and explicitly forbid the converse `Q -> P`
# and inverse `not P -> not Q`.
#
# **Go/no-go:** if `implication_cot` flips `log-ind-001` (= 6737), `lr-001`, or `log-ind-003` that the
# others miss, the directional hypothesis is worth the full build (trap-labelled dataset + failure
# logging). If it moves nothing, 6737 is a capability ceiling and we stop.

# %%
from experiments.adaptive_routing import AdaptiveRoutingExperiment, IMPLICATION_PROBE_CONDITIONS

logic_qs = [q for q in questions if categories[q.qid] == 'logical_reasoning']
probe_path = AdaptiveRoutingExperiment(
    engine, conditions=IMPLICATION_PROBE_CONDITIONS,
    out_dir='experiments/adaptive_routing_implication', max_new_tokens=512,
).run(logic_qs, categories, verbose=True)
probe_path
# Out:
# === Condition cot_v2: Current Maths fallback (brevity-capped) ===
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#   [1/52] lr-001  cot_v2         strat=cot_v2                      -> B (gold D) [  X]
#   [2/52] lr-002  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [3/52] lr-003  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [4/52] lr-004  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [5/52] lr-005  cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [6/52] log-ind-001 cot_v2         strat=cot_v2                      -> C (gold D) [  X]
#   [7/52] log-ind-002 cot_v2         strat=cot_v2                      -> A (gold A) [ok ]
#   [8/52] log-ind-003 cot_v2         strat=cot_v2                      -> C (gold C) [ok ]
#   [9/52] log-ind-004 cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [10/52] log-ind-005 cot_v2         strat=cot_v2                      -> D (gold D) [ok ]
#   [11/52] log-stat-001 cot_v2         strat=cot_v2                      -> B (gold B) [ok ]
#   [12/52] log-stat-002 cot_v2         strat=cot_v2                      -> A (gold A) [ok ]
#   [13/52] log-stat-003 cot_v2         strat=cot_v2                      -> C (gold C) [ok ]
#
# === Condition generic_cot: Step-by-step, no cap ===
#   [14/52] lr-001  generic_cot    strat=generic_cot                 -> B (gold D) [  X]
#   [15/52] lr-002  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [16/52] lr-003  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [17/52] lr-004  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [18/52] lr-005  generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [19/52] log-ind-001 generic_cot    strat=generic_cot                 -> C (gold D) [  X]
#   [20/52] log-ind-002 generic_cot    strat=generic_cot                 -> A (gold A) [ok ]
#   [21/52] log-ind-003 generic_cot    strat=generic_cot                 -> C (gold C) [ok ]
#   [22/52] log-ind-004 generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [23/52] log-ind-005 generic_cot    strat=generic_cot                 -> D (gold D) [ok ]
#   [24/52] log-stat-001 generic_cot    strat=generic_cot                 -> B (gold B) [ok ]
#   [25/52] log-stat-002 generic_cot    strat=generic_cot                 -> A (gold A) [ok ]
#   [26/52] log-stat-003 generic_cot    strat=generic_cot                 -> C (gold C) [ok ]
#
# === Condition checklist_cot: Per-option verification checklist ===
#   [27/52] lr-001  checklist_cot  strat=checklist_cot               -> B (gold D) [  X]
#   [28/52] lr-002  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [29/52] lr-003  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [30/52] lr-004  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [31/52] lr-005  checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [32/52] log-ind-001 checklist_cot  strat=checklist_cot               -> A (gold D) [  X]
#   [33/52] log-ind-002 checklist_cot  strat=checklist_cot               -> A (gold A) [ok ]
#   [34/52] log-ind-003 checklist_cot  strat=checklist_cot               -> B (gold C) [  X]
#   [35/52] log-ind-004 checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [36/52] log-ind-005 checklist_cot  strat=checklist_cot               -> D (gold D) [ok ]
#   [37/52] log-stat-001 checklist_cot  strat=checklist_cot               -> B (gold B) [ok ]
#   [38/52] log-stat-002 checklist_cot  strat=checklist_cot               -> A (gold A) [ok ]
#   [39/52] log-stat-003 checklist_cot  strat=checklist_cot               -> C (gold C) [ok ]
#
# === Condition implication_cot: Explicit logical-direction scaffold (P->Q, contrapositive) ===
#   [40/52] lr-001  implication_cot strat=implication_cot             -> B (gold D) [  X]
#   [41/52] lr-002  implication_cot strat=implication_cot             -> B (gold B) [ok ]
#   [42/52] lr-003  implication_cot strat=implication_cot             -> B (gold B) [ok ]
#   [43/52] lr-004  implication_cot strat=implication_cot             -> B (gold B) [ok ]
#   [44/52] lr-005  implication_cot strat=implication_cot             -> B (gold B) [ok ]
#   [45/52] log-ind-001 implication_cot strat=implication_cot             -> C (gold D) [  X]
#   [46/52] log-ind-002 implication_cot strat=implication_cot             -> A (gold A) [ok ]
#   [47/52] log-ind-003 implication_cot strat=implication_cot             -> C (gold C) [ok ]
#   [48/52] log-ind-004 implication_cot strat=implication_cot             -> B (gold B) [ok ]
#   [49/52] log-ind-005 implication_cot strat=implication_cot             -> D (gold D) [ok ]
#   [50/52] log-stat-001 implication_cot strat=implication_cot             -> B (gold B) [ok ]
#   [51/52] log-stat-002 implication_cot strat=implication_cot             -> A (gold A) [ok ]
#   [52/52] log-stat-003 implication_cot strat=implication_cot             -> C (gold C) [ok ]
#
# Wrote 52 records -> experiments/adaptive_routing_implication/records.jsonl
# 'experiments/adaptive_routing_implication/records.jsonl'

# %% [markdown]
# ### 13.1 · Per-condition accuracy + per-question decision table

# %%
import pandas as pd
pdf = analysis.load_records(probe_path)
order = [c.name for c in IMPLICATION_PROBE_CONDITIONS]
display(pdf.groupby('condition')['correct'].agg(accuracy='mean', n='count').reindex(order))
piv = pdf.pivot_table(index='qid', columns='condition', values='correct').reindex(columns=order)
piv = piv.reindex([q.qid for q in logic_qs])
piv
# Out:
#                  accuracy   n
# condition
# cot_v2           0.846154  13
# generic_cot      0.846154  13
# checklist_cot    0.769231  13
# implication_cot  0.846154  13
# condition     cot_v2  generic_cot  checklist_cot  implication_cot
# qid
# lr-001           0.0          0.0            0.0              0.0
# lr-002           1.0          1.0            1.0              1.0
# lr-003           1.0          1.0            1.0              1.0
# lr-004           1.0          1.0            1.0              1.0
# lr-005           1.0          1.0            1.0              1.0
# log-ind-001      0.0          0.0            0.0              0.0
# log-ind-002      1.0          1.0            1.0              1.0
# log-ind-003      1.0          1.0            0.0              1.0
# log-ind-004      1.0          1.0            1.0              1.0
# log-ind-005      1.0          1.0            1.0              1.0
# log-stat-001     1.0          1.0            1.0              1.0
# log-stat-002     1.0          1.0            1.0              1.0
# log-stat-003     1.0          1.0            1.0              1.0

# %% [markdown]
# ### 13.2 · The decisive rows — did the scaffold fix what the others missed?

# %%
# Focus on the questions the other prompts FAIL: 6737 (log-ind-001), lr-001, log-ind-003.
focus = ['log-ind-001', 'lr-001', 'log-ind-003']
print(piv.reindex(focus).to_string())
print()
for qid in focus:
    row = pdf[(pdf.qid==qid) & (pdf.condition=='implication_cot')]
    if len(row):
        r = row.iloc[0]
        print(f'=== {qid}  implication_cot -> {r.predicted_answer} (gold {r.gold_answer})  '
              f'{"CORRECT" if r.correct else "WRONG"} ===')
        print(r.raw_output[:700]); print()
# Out:
# condition    cot_v2  generic_cot  checklist_cot  implication_cot
# qid
# log-ind-001     0.0          0.0            0.0              0.0
# lr-001          0.0          0.0            0.0              0.0
# log-ind-003     1.0          1.0            0.0              1.0
#
# === log-ind-001  implication_cot -> C (gold D)  WRONG ===
# The given conditions imply that if \( S(k) \) is false for some \( k \geq n_0 \), then \( S(k-1) \) must also be false, and this logic propagates backward. This means that once \( S(n_0) \) is false, all previous statements \( S(n) \) for \( n < n_0 \) must also be false.
#
# Let's test each option:
#
# A) \( S(n_0 - 1) \) is not true.
#    - This is not necessarily true because we only know that \( S(n_0) \) is false, but we don't have information about \( S(n_0 - 1) \).
#
# B) \( S(n_0 + 1) \) is not true.
#    - This is not necessarily true because the problem does not provide information about \( S(n_0 + 1) \).
#
# C) \( S(n) \) is not true for any \( n \geq n_0 \).
#    - This is true based on the given
#
# === lr-001  implication_cot -> B (gold D)  WRONG ===
# 1. The given statements can be written as:
#    - All roses are flowers. (Roses → Flowers)
#    - Some flowers fade quickly. (Some F)
#
# 2. The contrapositive of "All roses are flowers" is: If something is not a flower, then it is not a rose. (¬Flowers → ¬Roses)
#
# 3. Testing each option:
#    - A) All roses fade quickly. (Roses → Fade Quickly)
#      This cannot be concluded from the given information. We only know that some flowers fade quickly, but we don't know if all roses are among those that fade quickly.
#    - B) Some roses fade quickly. (Some R → Fade Quickly)
#      Since some flowers fade quickly and all roses are flowers, it logically follows that some roses must fade quickly.
#    - C) All flowe
#
# === log-ind-003  implication_cot -> C (gold C)  CORRECT ===
# 1. The given statement is "If a number is divisible by 6, then it is divisible by 3." This can be written as the implication \( P \rightarrow Q \), where \( P \) is "a number is divisible by 6" and \( Q \) is "a number is divisible by 3".
#
# 2. The contrapositive of \( P \rightarrow Q \) is \( \neg Q \rightarrow \neg P \), which translates to "If a number is not divisible by 3, then it is not divisible by 6."
#
# 3. Testing each option:
#    - A) It is divisible by 2: We cannot conclude this from the given information.
#    - B) Nothing can be concluded: This is not necessarily true because we can conclude something from the given information.
#    - C) It is not divisible by 6: This directly follows f

# %% [markdown]
# ### 13.3 · Verdict
#
# - **implication_cot fixes ≥1 of the focus rows** (esp. 6737) → proceed to the full build: a trap-labelled
#   directional-logic dataset (converse / inverse / contrapositive / induction-up / induction-down), the
#   metadata-driven failure logging (converse/inverse/contrapositive/induction-direction confusion), and
#   wiring `logical_reasoning -> implication_cot` into the Maths policy.
# - **implication_cot moves nothing** → 6737 is a 7B capability ceiling; record the negative result and stop.
