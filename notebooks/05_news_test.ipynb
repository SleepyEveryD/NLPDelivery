# %% [markdown]
# # Who Wants to Be a PoliMillionaire? — NLP 2025/26 Group Assignment
#
# ## Group members
# - Jiaxin Yang — jiaxin.yang@mail.polimi.it
# - Runjie (Simone) Dai — runjie.dai@mail.polimi.it
#
# ## Video
# <!-- ⚠️ Only item to fill before submission: replace TODO_LINK with the presentation video link -->
# - Presentation video (≤5 min): **TODO_LINK**
#
# ## Statement on coding assistants
# We used a coding assistant (Claude Code) to help write, refactor and document parts of the implementation. The system design, the experiments, the prompt/RAG/routing strategies and all analysis are our own; the assignment was **not** handed to an LLM to complete.

# %% [markdown]
# # 05 · Live stress-test — 10 rounds, logged for analysis
#
# A `TARGET` switch (cell 2) picks the race:
# - **`'news'`** — competition 5, the live-web RAG pipeline (Guardian API + headless-Chromium bodies).
# - **`'math'`** — competition 3, the `pipeline_maths` recipe from notebook 03 (adaptive `cot_v2` /
#   `structured_enumeration_cot` routing, **no** retrieval, **no** calculator, `max_new_tokens=450`).
#
# Plays the chosen competition **10 times back to back**, each round its own logged run
# (`{target}_r01`..`{target}_r10`), then aggregates everything — per-round accuracy + reached level, and
# **every wrong question with its diagnostics** (News: the retrieved evidence; Math: the reasoning chain,
# which routing strategy fired, and whether it hit the token cap). The output dir keys off `TARGET`
# (`experiments/news_test/` or `experiments/math_test/`).
#
# > Leaderboard attempts are FREE (only the cumulative best counts), so re-running 10 rounds costs us
# > nothing on the board. We still pause politely between games (the PDF asks: no rapid requests).
# > The RAG-vs-noRAG ablation (last section) is **News-only**.

# %% [markdown]
# ## 1 · Setup — clone/sync the repo, paths, the provided client

# %%
# Auto-reload edited src modules on every cell run -- so after a `git pull` the newest code lands without a
# manual importlib.reload or a restart. (Re-run the cell that USES the code, e.g. code-wire.)
# Colab's IPython ships an autoreload that does `from imp import reload`, and `imp` is GONE in Python 3.12 --
# so a tiny `imp` shim (reload only) we install first, then load the extension. BEST-EFFORT: any failure
# caught, so the cell never stalls (fall back: after a src pull, Runtime > Restart to pick changes up).
try:
    import sys as _sys, types as _types, importlib as _importlib
    if 'imp' not in _sys.modules:
        _imp = _types.ModuleType('imp')
        _imp.reload = _importlib.reload          # the one thing the old autoreload.py wants from `imp`.
        _sys.modules['imp'] = _imp
    _ip = get_ipython()
    _ip.run_line_magic('load_ext', 'autoreload')
    _ip.run_line_magic('autoreload', '2')
    print('autoreload: ON (src edits hot-reload on cell re-run)')
except Exception as _e:
    print(f'autoreload OFF ({type(_e).__name__}: {_e}) -- after a src pull, Runtime > Restart to pick changes up.')

import os, sys

REPO_URL = 'https://github.com/SleepyEveryD/NLP.git'
REPO_ROOT = '/content/NLP'
BRANCH = 'science'
if not os.path.exists(REPO_ROOT):
  # !git clone -b {BRANCH} {REPO_URL} {REPO_ROOT}
else:
  # Already cloned -> HARD-SYNC to the latest pushed branch (fetch + force-reset to origin/{BRANCH}).
  # Tracked files are overwritten to match remote; UNTRACKED run outputs are KEPT (experiments/runs/* is
  # gitignored). NOTE: `git pull` updates the FILES on disk -- it does NOT refresh THIS notebook's cells.
  # !cd {REPO_ROOT} && git fetch -q origin && git checkout -q -f -B {BRANCH} origin/{BRANCH}

# !cd {REPO_ROOT} && echo "on branch:" $(git rev-parse --abbrev-ref HEAD) "@" $(git --no-pager log -1 --oneline)

SRC = os.path.join(REPO_ROOT, 'src')
API_CLIENT = os.path.join(REPO_ROOT, 'NLP_assignment_api_client')
for p in (SRC, API_CLIENT):
  if p not in sys.path:
    sys.path.insert(0, p)
os.chdir(REPO_ROOT)
print('Repo root:', REPO_ROOT)

from millionaire_client import MillionaireClient
print('millionaire_client, imported it is.')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# autoreload: ON (src edits hot-reload on cell re-run)
# on branch: science @ 9713b3e test science
# Repo root: /content/NLP
# millionaire_client, imported it is.

# %%
# The inference stack + the client's `requests`, install we do (light it stays). `-U` kept (Colab a stale
# bitsandbytes preinstalls); pandas/requests PINNED to Colab's versions (bare `-U` breaks google-colab/cudf).
# !pip install -q -U 'transformers>=4.45.0' 'accelerate>=0.34.0' 'bitsandbytes>=0.46.1' sentencepiece einops pyyaml 'pandas==2.2.2' matplotlib 'requests==2.32.4'
print('Installed, the dependencies are.')
# Out:
# Installed, the dependencies are.

# %%
# Headless Chromium -- the live-NEWS body fetch it powers (configs/live.yaml: news_body_mode "browser").
# The relevance gate now ROUTES off-topic Guardian results here, so the browser matters MORE for News.
# Skip this only if you set retrieval.news_body_mode: "off".
# !pip install -q playwright
# !playwright install chromium
# !playwright install-deps

# ARMED? a REAL launch the surest test is. NOT ready -> News falls back to HEADLINES only (crash-safe).
try:
    from playwright.sync_api import sync_playwright
    with sync_playwright() as _p:
        _b = _p.chromium.launch(headless=True); _b.close()
    print('headless Chromium: READY -- live-News body fetch armed.')
except Exception as _e:
    print(f'headless Chromium NOT ready ({type(_e).__name__}: {_e})')
    print('   -> News will use HEADLINES only. Re-run this cell, or set retrieval.news_body_mode: "off".')
# Out:
# Removing unused browser at /root/.cache/ms-playwright/chromium_headless_shell-1223
# Downloading Chrome Headless Shell 148.0.7778.96 (playwright chromium-headless-shell v1223) from https://cdn.playwright.dev/builds/cft/148.0.7778.96/linux64/chrome-headless-shell-linux64.zip
# 113.2 MiB [] 0% 0.0s113.2 MiB [] 0% 16.0s113.2 MiB [] 0% 9.0s113.2 MiB [] 0% 6.5s113.2 MiB [] 2% 2.8s113.2 MiB [] 2% 2.9s113.2 MiB [] 3% 3.2s113.2 MiB [] 3% 3.1s113.2 MiB [] 4% 3.1s113.2 MiB [] 5% 3.0s113.2 MiB [] 6% 2.8s113.2 MiB [] 7% 2.5s113.2 MiB [] 8% 2.3s113.2 MiB [] 10% 2.0s113.2 MiB [] 10% 2.1s113.2 MiB [] 11% 2.0s113.2 MiB [] 12% 2.1s113.2 MiB [] 12% 2.2s113.2 MiB [] 14% 2.0s113.2 MiB [] 15% 1.8s113.2 MiB [] 17% 1.7s113.2 MiB [] 19% 1.6s113.2 MiB [] 20% 1.5s113.2 MiB [] 22% 1.4s113.2 MiB [] 23% 1.4s113.2 MiB [] 24% 1.3s113.2 MiB [] 26% 1.3s113.2 MiB [] 27% 1.2s113.2 MiB [] 29% 1.2s113.2 MiB [] 31% 1.1s113.2 MiB [] 32% 1.1s113.2 MiB [] 33% 1.1s113.2 MiB [] 34% 1.1s113.2 MiB [] 37% 1.0s113.2 MiB [] 39% 1.0s113.2 MiB [] 41% 0.9s113.2 MiB [] 43% 0.8s113.2 MiB [] 46% 0.8s113.2 MiB [] 48% 0.7s113.2 MiB [] 50% 0.7s113.2 MiB [] 53% 0.6s113.2 MiB [] 55% 0.6s113.2 MiB [] 57% 0.6s113.2 MiB [] 59% 0.5s113.2 MiB [] 60% 0.5s113.2 MiB [] 62% 0.5s113.2 MiB [] 64% 0.5s113.2 MiB [] 66% 0.4s113.2 MiB [] 67% 0.4s113.2 MiB [] 68% 0.4s113.2 MiB [] 69% 0.4s113.2 MiB [] 71% 0.4s113.2 MiB [] 73% 0.4s113.2 MiB [] 75% 0.3s113.2 MiB [] 76% 0.3s113.2 MiB [] 77% 0.3s113.2 MiB [] 79% 0.3s113.2 MiB [] 82% 0.2s113.2 MiB [] 83% 0.2s113.2 MiB [] 85% 0.2s113.2 MiB [] 86% 0.2s113.2 MiB [] 88% 0.2s113.2 MiB [] 89% 0.1s113.2 MiB [] 90% 0.1s113.2 MiB [] 91% 0.1s113.2 MiB [] 93% 0.1s113.2 MiB [] 94% 0.1s113.2 MiB [] 96% 0.0s113.2 MiB [] 99% 0.0s113.2 MiB [] 100% 0.0s
# Chrome Headless Shell 148.0.7778.96 (playwright chromium-headless-shell v1223) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1223
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-liberation is already the newest version (1:1.07.4-11).
# libegl1 is already the newest version (1.4.0-1).
# libepoxy0 is already the newest version (1.5.10-1).
# libepoxy0 set to manually installed.
# libevent-2.1-7 is already the newest version (2.1.12-stable-1build3).
# libevent-2.1-7 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libgles2 is already the newest version (1.4.0-1).
# libglx0 is already the newest version (1.4.0-1).
# libglx0 set to manually installed.
# libicu70 is already the newest version (70.1-2).
# libicu70 set to manually installed.
# libjpeg-turbo8 is already the newest version (2.1.2-0ubuntu1).
# libjpeg-turbo8 set to manually installed.
# libopengl0 is already the newest version (1.4.0-1).
# libopus0 is already the newest version (1.3.1-0.1build2).
# libopus0 set to manually installed.
# libxcb-shm0 is already the newest version (1.14-3ubuntu3).
# libxcb-shm0 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcursor1 is already the newest version (1:1.2.0-2build4).
# libxcursor1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1build4).
# libx264-163 is already the newest version (2:0.163.3060+git5db6aa6-2build1).
# libx264-163 set to manually installed.
# libasound2 is already the newest version (1.2.6.1-1ubuntu1.1).
# libasound2 set to manually installed.
# libatomic1 is already the newest version (12.3.0-1ubuntu1~22.04.3).
# libatomic1 set to manually installed.
# libcairo-gobject2 is already the newest version (1.16.0-5ubuntu2.1).
# libcairo-gobject2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2.1).
# libcairo2 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.16).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libgdk-pixbuf-2.0-0 is already the newest version (2.42.8+dfsg-1ubuntu0.5).
# libgdk-pixbuf-2.0-0 set to manually installed.
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.9).
# libgstreamer1.0-0 is already the newest version (1.20.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# libgtk-4-1 is already the newest version (4.6.9+ds-0ubuntu0.22.04.2).
# libgtk-4-1 set to manually installed.
# libharfbuzz0b is already the newest version (2.7.4-1ubuntu3.2).
# libharfbuzz0b set to manually installed.
# liblcms2-2 is already the newest version (2.12~rc1-2ubuntu0.1).
# liblcms2-2 set to manually installed.
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.3).
# libnss3 set to manually installed.
# libopenjp2-7 is already the newest version (2.4.0-6ubuntu0.5).
# libopenjp2-7 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpangocairo-1.0-0 set to manually installed.
# libpng16-16 is already the newest version (1.6.37-3ubuntu0.5).
# libpng16-16 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libwayland-egl1 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-egl1 set to manually installed.
# libwayland-server0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-server0 set to manually installed.
# libwebpdemux2 is already the newest version (1.2.2-2ubuntu0.22.04.2).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# libx11-xcb1 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-xcb1 set to manually installed.
# libxml2 is already the newest version (2.9.13+dfsg-1ubuntu0.11).
# libxml2 set to manually installed.
# libxslt1.1 is already the newest version (1.1.34-4ubuntu0.22.04.5).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   dictionaries-common glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas hunspell-en-us libaa1
#   libabsl20210324 libaspell15 libatk1.0-data libcdparanoia0 libdca0 libdv4
#   libdvdnav4 libdvdread8 libfaad2 libfluidsynth3 libfreeaptx0 libgav1-0
#   libgssdp-1.2-0 libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-good1.0-0
#   libgtk-3-common libgupnp-1.2-1 libgupnp-igd-1.0-4 libhunspell-1.7-0
#   libilmbase25 libinstpatch-1.0-2 libjson-glib-1.0-0 libjson-glib-1.0-common
#   libkate1 libldacbt-enc2 libltc11 libmjpegutils-2.1-0 libmodplug1 libmpcdec6
#   libmpeg2encpp-2.1-0 libmplex2-2.1-0 libnice10 libopenexr25 libopenh264-6
#   libopenni2-0 liborc-0.4-0 libqrencode4 libsbc1 libsecret-common libshout3
#   libsoundtouch1 libsoup-3.0-common libsoup2.4-1 libsoup2.4-common libspandsp2
#   libsrtp2-1 libtag1v5 libtag1v5-vanilla libtext-iconv-perl libv4l-0
#   libv4lconvert0 libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0 libwavpack1
#   libwebrtc-audio-processing1 libwildmidi2 libyuv0 libzbar0 libzxingcore1
#   session-migration timgm6mb-soundfont xfonts-encodings xfonts-utils
# Suggested packages:
#   ispell | aspell | hunspell wordlist frei0r-plugins gvfs hunspell
#   openoffice.org-hunspell | openoffice.org-core aspell libdv-bin oss-compat
#   libdvdcss2 libenchant-2-voikko libvisual-0.4-plugins gnome-shell
#   | notification-daemon libwildmidi-config fluid-soundfont-gm
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma gstreamer1.0-x aspell-en
#   | aspell-dictionary | aspell6a-dictionary at-spi2-core enchant-2
#   gstreamer1.0-gl libgtk-3-bin librsvg2-common libmagickcore-6.q16-6-extra
# The following NEW packages will be installed:
#   dictionaries-common fonts-freefont-ttf fonts-ipafont-gothic
#   fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei
#   glib-networking glib-networking-common glib-networking-services
#   gsettings-desktop-schemas gstreamer1.0-libav gstreamer1.0-plugins-bad
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good hunspell-en-us libaa1
#   libabsl20210324 libaspell15 libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libavif13 libcdparanoia0 libdbus-glib-1-2 libdca0 libdv4
#   libdvdnav4 libdvdread8 libenchant-2-2 libevdev2 libfaad2 libffi7
#   libfluidsynth3 libfreeaptx0 libgav1-0 libgssdp-1.2-0 libgstreamer-gl1.0-0
#   libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgtk-3-0 libgtk-3-common libgudev-1.0-0
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libharfbuzz-icu0 libhunspell-1.7-0
#   libhyphen0 libilmbase25 libinstpatch-1.0-2 libjson-glib-1.0-0
#   libjson-glib-1.0-common libkate1 libldacbt-enc2 libltc11 libmanette-0.2-0
#   libmjpegutils-2.1-0 libmodplug1 libmpcdec6 libmpeg2encpp-2.1-0
#   libmplex2-2.1-0 libnice10 libnotify4 libopenexr25 libopenh264-6 libopenni2-0
#   liborc-0.4-0 libproxy1v5 libqrencode4 libsbc1 libsecret-1-0 libsecret-common
#   libshout3 libsoundtouch1 libsoup-3.0-0 libsoup-3.0-common libsoup2.4-1
#   libsoup2.4-common libspandsp2 libsrtp2-1 libtag1v5 libtag1v5-vanilla
#   libtext-iconv-perl libv4l-0 libv4lconvert0 libvisual-0.4-0 libvo-aacenc0
#   libvo-amrwbenc0 libwavpack1 libwebrtc-audio-processing1 libwildmidi2
#   libwoff1 libxcomposite1 libxtst6 libyuv0 libzbar0 libzxingcore1
#   session-migration timgm6mb-soundfont xfonts-cyrillic xfonts-encodings
#   xfonts-scalable xfonts-utils
# 0 upgraded, 105 newly installed, 0 to remove and 64 not upgraded.
# Need to get 53.7 MB of archives.
# After this operation, 142 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3,718 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9,982 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.6 [848 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-libav amd64 1.20.3-0ubuntu1 [103 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.6 [712 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaa1 amd64 1.4p5-50build1 [51.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdv4 amd64 1.0.0-14build1 [61.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.20.3-0ubuntu1.6 [30.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libshout3 amd64 2.4.5-1build3 [54.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-3ubuntu3 [304 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-3ubuntu3 [11.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-common all 2.74.2-3ubuntu0.6 [4,778 B]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-1 amd64 2.74.2-3ubuntu0.6 [288 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-good amd64 1.20.3-0ubuntu1.6 [2,006 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libabsl20210324 amd64 0~20210324.2-2ubuntu0.3 [386 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaspell15 amd64 0.60.8-4build1 [325 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgav1-0 amd64 0.17.0-1build1 [336 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libyuv0 amd64 0.0~git20220104.b91df1a-2 [154 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libavif13 amd64 0.9.3-3 [69.5 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbus-glib-1-2 amd64 0.112-2build1 [65.4 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdread8 amd64 6.1.2-1 [55.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdnav4 amd64 6.1.1-1 [39.3 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libenchant-2-2 amd64 2.3.2-1ubuntu2 [50.9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfaad2 amd64 2.10.0-2 [197 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libffi7 amd64 3.3-5ubuntu1 [19.9 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfreeaptx0 amd64 0.1.1-1 [12.9 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgssdp-1.2-0 amd64 1.4.0.1-2build1 [48.9 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.6 [204 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgupnp-1.2-1 amd64 1.4.3-1 [93.3 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgupnp-igd-1.0-4 amd64 1.2.0-1build1 [16.8 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.2 [5,890 B]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4,432 B]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkate1 amd64 0.4.1-11build1 [39.4 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldacbt-enc2 amd64 2.0.2.3+git20200429+ed310a0-4 [24.6 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libltc11 amd64 1.3.1-1 [12.3 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmanette-0.2-0 amd64 0.2.6-3build1 [30.4 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmjpegutils-2.1-0 amd64 1:2.1.0+debian-6build1 [24.1 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpcdec6 amd64 2:0.1~r495-2 [32.4 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpeg2encpp-2.1-0 amd64 1:2.1.0+debian-6build1 [69.4 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmplex2-2.1-0 amd64 1:2.1.0+debian-6build1 [44.4 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnice10 amd64 0.1.18-2 [156 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenh264-6 amd64 2.2.0+dfsg-2 [407 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenni2-0 amd64 2.2.0.33+dfsg-15 [389 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqrencode4 amd64 4.1.1-1 [24.0 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-common all 0.20.5-2 [4,278 B]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-1-0 amd64 0.20.5-2 [124 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsoundtouch1 amd64 2.3.1+ds1-1 [38.3 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-common all 3.0.7-0ubuntu1 [62.1 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-0 amd64 3.0.7-0ubuntu1 [278 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrtp2-1 amd64 2.4.2-2 [40.7 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu5 [291 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzbar0 amd64 0.23.92-4build2 [121 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzxingcore1 amd64 1.2.0-1 [619 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdca0 amd64 0.0.7-2 [88.2 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.20.3-0ubuntu1.1 [489 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-aacenc0 amd64 0.1.3-2 [69.4 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2 [68.2 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-plugins-bad amd64 1.20.3-0ubuntu1.1 [2,602 kB]
# Fetched 53.7 MB in 2s (33.5 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 122402 files and directories currently installed.)
# Preparing to unpack .../000-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../001-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../002-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../003-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../004-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../005-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-unifont.
# Preparing to unpack .../006-fonts-unifont_1%3a14.0.01-1_all.deb ...
# Unpacking fonts-unifont (1:14.0.01-1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../007-fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../008-libproxy1v5_0.4.17-2_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.17-2) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../009-glib-networking-common_2.72.0-1_all.deb ...
# Unpacking glib-networking-common (2.72.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../010-glib-networking-services_2.72.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.72.0-1) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../011-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../012-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../013-glib-networking_2.72.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.72.0-1) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../014-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../015-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package gstreamer1.0-libav:amd64.
# Preparing to unpack .../016-gstreamer1.0-libav_1.20.3-0ubuntu1_amd64.deb ...
# Unpacking gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../017-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../018-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../019-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../020-libaa1_1.4p5-50build1_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-50build1) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../021-libdv4_1.0.0-14build1_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-14build1) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../022-libgstreamer-plugins-good1.0-0_1.20.3-0ubuntu1.6_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.6) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../023-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../024-libshout3_2.4.5-1build3_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.5-1build3) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../025-libtag1v5-vanilla_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../026-libtag1v5_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../027-libv4lconvert0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../028-libv4l-0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../029-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsoup2.4-common.
# Preparing to unpack .../030-libsoup2.4-common_2.74.2-3ubuntu0.6_all.deb ...
# Unpacking libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../031-libsoup2.4-1_2.74.2-3ubuntu0.6_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../032-gstreamer1.0-plugins-good_1.20.3-0ubuntu1.6_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.6) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../033-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libabsl20210324:amd64.
# Preparing to unpack .../034-libabsl20210324_0~20210324.2-2ubuntu0.3_amd64.deb ...
# Unpacking libabsl20210324:amd64 (0~20210324.2-2ubuntu0.3) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../035-libaspell15_0.60.8-4build1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-4build1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../036-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../037-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../038-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../039-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libgav1-0:amd64.
# Preparing to unpack .../040-libgav1-0_0.17.0-1build1_amd64.deb ...
# Unpacking libgav1-0:amd64 (0.17.0-1build1) ...
# Selecting previously unselected package libyuv0:amd64.
# Preparing to unpack .../041-libyuv0_0.0~git20220104.b91df1a-2_amd64.deb ...
# Unpacking libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Selecting previously unselected package libavif13:amd64.
# Preparing to unpack .../042-libavif13_0.9.3-3_amd64.deb ...
# Unpacking libavif13:amd64 (0.9.3-3) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../043-libdbus-glib-1-2_0.112-2build1_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Selecting previously unselected package libdvdread8:amd64.
# Preparing to unpack .../044-libdvdread8_6.1.2-1_amd64.deb ...
# Unpacking libdvdread8:amd64 (6.1.2-1) ...
# Selecting previously unselected package libdvdnav4:amd64.
# Preparing to unpack .../045-libdvdnav4_6.1.1-1_amd64.deb ...
# Unpacking libdvdnav4:amd64 (6.1.1-1) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../046-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../047-libenchant-2-2_2.3.2-1ubuntu2_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Selecting previously unselected package libfaad2:amd64.
# Preparing to unpack .../048-libfaad2_2.10.0-2_amd64.deb ...
# Unpacking libfaad2:amd64 (2.10.0-2) ...
# Selecting previously unselected package libffi7:amd64.
# Preparing to unpack .../049-libffi7_3.3-5ubuntu1_amd64.deb ...
# Unpacking libffi7:amd64 (3.3-5ubuntu1) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../050-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../051-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../052-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package libfreeaptx0:amd64.
# Preparing to unpack .../053-libfreeaptx0_0.1.1-1_amd64.deb ...
# Unpacking libfreeaptx0:amd64 (0.1.1-1) ...
# Selecting previously unselected package libgssdp-1.2-0:amd64.
# Preparing to unpack .../054-libgssdp-1.2-0_1.4.0.1-2build1_amd64.deb ...
# Unpacking libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../055-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.6_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../056-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../057-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../058-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgupnp-1.2-1:amd64.
# Preparing to unpack .../059-libgupnp-1.2-1_1.4.3-1_amd64.deb ...
# Unpacking libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Selecting previously unselected package libgupnp-igd-1.0-4:amd64.
# Preparing to unpack .../060-libgupnp-igd-1.0-4_1.2.0-1build1_amd64.deb ...
# Unpacking libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../061-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../062-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../063-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libjson-glib-1.0-common.
# Preparing to unpack .../064-libjson-glib-1.0-common_1.6.6-1build1_all.deb ...
# Unpacking libjson-glib-1.0-common (1.6.6-1build1) ...
# Selecting previously unselected package libjson-glib-1.0-0:amd64.
# Preparing to unpack .../065-libjson-glib-1.0-0_1.6.6-1build1_amd64.deb ...
# Unpacking libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Selecting previously unselected package libkate1:amd64.
# Preparing to unpack .../066-libkate1_0.4.1-11build1_amd64.deb ...
# Unpacking libkate1:amd64 (0.4.1-11build1) ...
# Selecting previously unselected package libldacbt-enc2:amd64.
# Preparing to unpack .../067-libldacbt-enc2_2.0.2.3+git20200429+ed310a0-4_amd64.deb ...
# Unpacking libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Selecting previously unselected package libltc11:amd64.
# Preparing to unpack .../068-libltc11_1.3.1-1_amd64.deb ...
# Unpacking libltc11:amd64 (1.3.1-1) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../069-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmanette-0.2-0:amd64.
# Preparing to unpack .../070-libmanette-0.2-0_0.2.6-3build1_amd64.deb ...
# Unpacking libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Selecting previously unselected package libmjpegutils-2.1-0:amd64.
# Preparing to unpack .../071-libmjpegutils-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../072-libmodplug1_1%3a0.8.9.0-3_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-3) ...
# Selecting previously unselected package libmpcdec6:amd64.
# Preparing to unpack .../073-libmpcdec6_2%3a0.1~r495-2_amd64.deb ...
# Unpacking libmpcdec6:amd64 (2:0.1~r495-2) ...
# Selecting previously unselected package libmpeg2encpp-2.1-0:amd64.
# Preparing to unpack .../074-libmpeg2encpp-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmplex2-2.1-0:amd64.
# Preparing to unpack .../075-libmplex2-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libnice10:amd64.
# Preparing to unpack .../076-libnice10_0.1.18-2_amd64.deb ...
# Unpacking libnice10:amd64 (0.1.18-2) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../077-libnotify4_0.7.9-3ubuntu5.22.04.1_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../078-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libopenh264-6:amd64.
# Preparing to unpack .../079-libopenh264-6_2.2.0+dfsg-2_amd64.deb ...
# Unpacking libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Selecting previously unselected package libopenni2-0:amd64.
# Preparing to unpack .../080-libopenni2-0_2.2.0.33+dfsg-15_amd64.deb ...
# Unpacking libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Selecting previously unselected package libqrencode4:amd64.
# Preparing to unpack .../081-libqrencode4_4.1.1-1_amd64.deb ...
# Unpacking libqrencode4:amd64 (4.1.1-1) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../082-libsecret-common_0.20.5-2_all.deb ...
# Unpacking libsecret-common (0.20.5-2) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../083-libsecret-1-0_0.20.5-2_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.20.5-2) ...
# Selecting previously unselected package libsoundtouch1:amd64.
# Preparing to unpack .../084-libsoundtouch1_2.3.1+ds1-1_amd64.deb ...
# Unpacking libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Selecting previously unselected package libsoup-3.0-common.
# Preparing to unpack .../085-libsoup-3.0-common_3.0.7-0ubuntu1_all.deb ...
# Unpacking libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Selecting previously unselected package libsoup-3.0-0:amd64.
# Preparing to unpack .../086-libsoup-3.0-0_3.0.7-0ubuntu1_amd64.deb ...
# Unpacking libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../087-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libsrtp2-1:amd64.
# Preparing to unpack .../088-libsrtp2-1_2.4.2-2_amd64.deb ...
# Unpacking libsrtp2-1:amd64 (2.4.2-2) ...
# Selecting previously unselected package libwebrtc-audio-processing1:amd64.
# Preparing to unpack .../089-libwebrtc-audio-processing1_0.3.1-0ubuntu5_amd64.deb ...
# Unpacking libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../090-libwildmidi2_0.4.3-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.3-1) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../091-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../092-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libzbar0:amd64.
# Preparing to unpack .../093-libzbar0_0.23.92-4build2_amd64.deb ...
# Unpacking libzbar0:amd64 (0.23.92-4build2) ...
# Selecting previously unselected package libzxingcore1:amd64.
# Preparing to unpack .../094-libzxingcore1_1.2.0-1_amd64.deb ...
# Unpacking libzxingcore1:amd64 (1.2.0-1) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../095-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../096-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../097-xfonts-cyrillic_1%3a1.0.5_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.5) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../098-xfonts-scalable_1%3a1.0.3-1.2ubuntu1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Selecting previously unselected package libdca0:amd64.
# Preparing to unpack .../099-libdca0_0.0.7-2_amd64.deb ...
# Unpacking libdca0:amd64 (0.0.7-2) ...
# Selecting previously unselected package libgstreamer-plugins-bad1.0-0:amd64.
# Preparing to unpack .../100-libgstreamer-plugins-bad1.0-0_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../101-libsbc1_1.5-3build2_amd64.deb ...
# Unpacking libsbc1:amd64 (1.5-3build2) ...
# Selecting previously unselected package libvo-aacenc0:amd64.
# Preparing to unpack .../102-libvo-aacenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-aacenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../103-libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package gstreamer1.0-plugins-bad:amd64.
# Preparing to unpack .../104-gstreamer1.0-plugins-bad_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libfreeaptx0:amd64 (0.1.1-1) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libsbc1:amd64 (1.5-3build2) ...
# Setting up libproxy1v5:amd64 (0.4.17-2) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libkate1:amd64 (0.4.1-11build1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libqrencode4:amd64 (4.1.1-1) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# Setting up fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libaspell15:amd64 (0.60.8-4build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libsrtp2-1:amd64 (2.4.2-2) ...
# Setting up libffi7:amd64 (3.3-5ubuntu1) ...
# Setting up libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Setting up libmpcdec6:amd64 (2:0.1~r495-2) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libvo-aacenc0:amd64 (0.1.3-2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up libdvdread8:amd64 (6.1.2-1) ...
# Setting up libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Setting up libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libfaad2:amd64 (2.10.0-2) ...
# Setting up libshout3:amd64 (2.4.5-1build3) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2ubuntu0.3) ...
# Setting up libltc11:amd64 (1.3.1-1) ...
# Setting up libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libdv4:amd64 (1.0.0-14build1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libzxingcore1:amd64 (1.2.0-1) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libdca0:amd64 (0.0.7-2) ...
# Setting up libjson-glib-1.0-common (1.6.6-1build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libsecret-common (0.20.5-2) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libdvdnav4:amd64 (6.1.1-1) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up libaa1:amd64 (1.4p5-50build1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Setting up libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libsecret-1-0:amd64 (0.20.5-2) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.6) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.6) ...
# Setting up libgav1-0:amd64 (0.17.0-1build1) ...
# Setting up libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libavif13:amd64 (0.9.3-3) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up libzbar0:amd64 (0.23.92-4build2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.6) ...
# Setting up libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Setting up libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Setting up libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Setting up libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Setting up libnice10:amd64 (0.1.18-2) ...
# Setting up gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# headless Chromium NOT ready (Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.)
#    -> News will use HEADLINES only. Re-run this cell, or set retrieval.news_body_mode: "off".

# %% [markdown]
# ## 2 · Config — pick the race (`TARGET`) + how many rounds

# %%
from config import RunConfig

config = RunConfig.from_yaml(os.path.join(REPO_ROOT, 'configs', 'live.yaml'))

# --- Pick which race to stress-test -------------------------------------------------------------
TARGET = 'science'   # any key of COMP_IDS below (e.g. 'science', 'history', 'philosophy', 'news', 'math', 'entertainment')
# ------------------------------------------------------------------------------------------------

# Every competition the harness can drive. The value is the server competition_id (confirm in the
# post-login list printed by cell 10). Order per configs/live.yaml: 0 Entertainment . 1 History .
# 2 Science . 3 Maths . 4 Philosophy . 5 News.
COMP_IDS = {
    'entertainment': 0,   # Entertainment                 -- knowledge RAG (FAISS/Wikipedia), few_shot_entertainment.
    'history':       1,   # Ancient History and Politics  -- knowledge RAG; in _HIGH_RETRIEVAL_TOPICS (always retrieves).
    'science':       2,   # Science and Nature            -- knowledge RAG; in _HIGH_RETRIEVAL_TOPICS (added 2026-06-02).
    'math':          3,   # Maths                         -- adaptive cot routing, NO RAG / NO tools.
    'philosophy':    4,   # Philosophy and Psychology     -- knowledge RAG; on-demand gate (not forced).
    'news':          5,   # News                          -- live-web RAG (Guardian API + headless Chromium).
}
assert TARGET in COMP_IDS, f'unknown TARGET {TARGET!r}; pick one of {sorted(COMP_IDS)}'

# Knowledge races -- the same `routed` retriever sends them to FAISS/Wikipedia (topic != News). They share
# one recipe; only Entertainment swaps in its own pop-culture exemplars (few_shot_entertainment).
KNOWLEDGE_TARGETS = {'entertainment', 'history', 'science', 'philosophy'}
# Anything that uses a retriever at all (knowledge RAG OR News web RAG). Only Maths runs retrieval-free, so
# the retrieval-flavoured diagnostics / ablation below key off this; Maths takes the reasoning-chain path.
RETRIEVAL_TARGET = TARGET != 'science'

COMP_ID    = COMP_IDS[TARGET]
NUM_ROUNDS = 10            # how many live games to play, back to back.
PAUSE_S    = 8.0          # polite gap between games (PDF: no rapid consecutive requests).

config.game.competition_id = COMP_ID
config.game.game_mode = 'text'

# The Guardian Open Platform key -- from a Colab secret (NEVER hardcoded). Only News uses it, but harmless
# to set always. With it, the Guardian fast body path is armed; the relevance gate keeps it ONLY on-topic.
try:
    from google.colab import userdata as _ud
    config.retrieval.guardian_api_key = _ud.get('guardian_key') or ''
except Exception:
    config.retrieval.guardian_api_key = config.retrieval.guardian_api_key or ''

print('TARGET:', TARGET, '| competition_id:', COMP_ID)
print('rounds:', NUM_ROUNDS, '| pause between:', PAUSE_S, 's')
print('aim_seconds:', config.game.aim_seconds, '| model:', config.model.name, '|', config.model.quantization)
if TARGET == 'news':
    print('News pipeline: few_shot_v1 + live-web RAG.')
    print('RAG:', 'ON' if config.retrieval.enabled else 'OFF', '| source:', config.retrieval.source,
          '| news_body_mode:', config.retrieval.news_body_mode, '| fetch_bodies:', config.retrieval.news_fetch_bodies)
    print('Guardian API:', 'KEY SET' if config.retrieval.guardian_api_key else 'no key -> News uses browser')
elif TARGET in KNOWLEDGE_TARGETS:
    strat = 'few_shot_entertainment' if TARGET == 'entertainment' else config.prompt_strategy
    print(f'{TARGET.capitalize()} pipeline: {strat} + RAG (routed -> FAISS/Wikipedia, gated by needs_retrieval).')
    print('RAG:', 'ON' if config.retrieval.enabled else 'OFF', '| source:', config.retrieval.source,
          '| top_k:', config.retrieval.top_k, '| min_score:', config.retrieval.min_score,
          '| bm25:', config.retrieval.bm25_index_path or 'off')
else:  # math
    print('Maths pipeline: adaptive cot_v2 / structured_enumeration_cot routing, NO retrieval, NO calculator,'
          ' max_new_tokens=450 (post-B3, 30s-wall safe).')
# Out:
# TARGET: science | competition_id: 2
# rounds: 10 | pause between: 8.0 s
# aim_seconds: 25.0 | model: Qwen/Qwen2.5-7B-Instruct | 4bit
# Science pipeline: few_shot_v1 + RAG (routed -> FAISS/Wikipedia, gated by needs_retrieval).
# RAG: ON | source: routed | top_k: 3 | min_score: 0.7 | bm25: off

# %% [markdown]
# ## 3 · Load + warm up the model

# %%
import time, gc
from inference.engine import TransformersEngine
import torch

# --- Free any leftover model from a PREVIOUS run BEFORE (re)loading ---------------------------------
# The Maths "model comparison" cell (TARGET='math') loads a SECOND model `engine_math` and frees `engine`.
# If that model's VRAM is still resident, the 4-bit base model no longer fits and bitsandbytes spills
# modules to the CPU -> the "Some modules are dispatched on the CPU or the disk" ValueError you hit.
# So drop `engine_math` and clear the CUDA cache first. A HEALTHY `engine` we keep (no reload, no wait).
if 'engine_math' in globals():
    del engine_math
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

t0 = time.perf_counter()
if 'engine' not in globals():
    engine = TransformersEngine(model_name=config.model.name,
                                quantization=config.model.quantization,
                                dtype=config.model.dtype)
    print(f'Model loaded in {time.perf_counter() - t0:.1f}s')
else:
    print('engine already in VRAM, skipping load.')

t0 = time.perf_counter()
engine.warmup()
print(f'Warmup in {time.perf_counter() - t0:.1f}s')
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded in 266.1s
# Warmup in 1.7s

# %% [markdown]
# ## 4 · Wire the pipeline for `TARGET` + log in to the game

# %%
from classify.classifier import QuestionClassifier
from prompting.builder import PromptBuilder, RoutingPromptBuilder
from classify.reasoning_router import MATHS_LIVE_POLICY, MATHS_LIVE_FALLBACK
from agent.pipeline import QAPipeline
from tools import default_tools, solve_maths
from retrieval import build_retriever

if RETRIEVAL_TARGET:
    # Phase 4 RAG: the routing retriever. News (post-cutoff) `routed` sends questions to the live web
    # (Guardian API + relevance gate -> headless-Chromium on the gnews link); every KNOWLEDGE race
    # (Entertainment / History / Science / Philosophy) routes the SAME `routed` retriever to FAISS/Wikipedia
    # (topic != News). `needs_retrieval` gates it per question.
    retriever = build_retriever(config.retrieval)
    print('RAG:', (f'ON  source={config.retrieval.source}  top_k={config.retrieval.top_k}') if retriever else 'OFF')

    # Per-race strategy: Entertainment gets its OWN `few_shot_entertainment` (pop-culture exemplars +
    # domain instruction, mirrors notebook 03's pipeline_entertainment); every other knowledge race AND News
    # keep config.prompt_strategy (few_shot_v1). All: RAG + the classifier-gated calculator no-op.
    strategy = 'few_shot_entertainment' if TARGET == 'entertainment' else config.prompt_strategy
    pipeline = QAPipeline(
        engine=engine,
        prompt_builder=PromptBuilder(strategy=strategy),
        classifier=QuestionClassifier(),
        retriever=retriever,
        tools=default_tools(),
        latency_budget_s=config.latency_budget_s,
    )
    print(f'{TARGET.capitalize()} pipeline wired:', strategy, '+ RAG (routed) + classifier-gated tools')

else:  # math -- EXACTLY the `pipeline_maths` recipe from notebook 03 (comp 3).
    # Adaptive routing: counting / temporal / discrete-enumeration -> structured_enumeration_cot; everything
    # else (arithmetic, logic, concept/stats) -> the cot_v2 fallback. NO retrieval (it only distracts on
    # Maths), NO calculator (at n=1 it clobbers the chain on numeric Qs), single-pass. max_new_tokens=450
    # (raised from 300 post-B3: only short time-interval Qs reach structured enum now, so chains finish in
    # 5-10s -- big headroom; 450 tok ~= 28s worst-case, dial to 400 if any Maths turn nears the 30s wall).
    pipeline = QAPipeline(
        engine=engine,
        prompt_builder=RoutingPromptBuilder(policy=MATHS_LIVE_POLICY, fallback_strategy=MATHS_LIVE_FALLBACK),
        classifier=QuestionClassifier(),
        retriever=None,
        tools=None,
        solver=solve_maths,   # deterministic type-specific solver: short-circuits the LLM on solvable types.
        latency_budget_s=config.latency_budget_s,
        max_new_tokens=450,
    )
    print('Maths pipeline wired: ADAPTIVE (counting/temporal/enum -> structured_enumeration_cot; else -> cot_v2)'
          ' + 450 tokens + single-pass + NO retrieval + NO general-calculator + DETERMINISTIC solver (solve_maths)')

# --- Log in to the real game ---
from google.colab import userdata
from game.client import GameClient

USERNAME = userdata.get('username')
PASSWORD = userdata.get('password')

game_client = GameClient()
game_client.login(USERNAME, PASSWORD)
print('Logged in as', USERNAME)

# The competitions + ids (safe -- starts no timer). Confirm the target's id here (News=5, Maths=3).
for c in game_client.list_competitions():
    print('  id=', c.id, '|', c.name, '| max_levels=', getattr(c, 'max_levels', '?'))
# Out:
# Maths pipeline wired: ADAPTIVE (counting/temporal/enum -> structured_enumeration_cot; else -> cot_v2) + 450 tokens + single-pass + NO retrieval + NO general-calculator + DETERMINISTIC solver (solve_maths)
# Logged in as runjie dai
#   id= 0 | Entertainment | max_levels= 15
#   id= 1 | Ancient History and Politics | max_levels= 15
#   id= 2 | Science and Nature | max_levels= 15
#   id= 3 | Maths | max_levels= 15
#   id= 4 | Philosophy and Psychology | max_levels= 15
#   id= 5 | News | max_levels= 15

# %% [markdown]
# ### 🔬 Core implementation: News live RAG -- a keyword retrieval cascade + date re-ranking + body focusing
#
# News (competition 5) uses live web RAG. **Strictly following the assignment rules**: only free sources that return **raw, non-generated content** (Google News RSS, the Guardian API's `bodyText`, body HTML scraped via headless Chromium) -- never any LLM-generated answer. The source names are called out in the video.
#
# The core is the **retrieval cascade** of `WebSearchRetriever.retrieve()` (`src/retrieval/retriever.py`): a full-sentence query is often shattered into 0 hits by gnews's AND matching, so it falls back step by step to shorter, sharper queries, then re-ranks by the question date, and finally fetches the body:
#
# ```python
# def retrieve(self, question: Question) -> list[RetrievedDoc]:
#     query = _query_from_question(question)
#
#     # 1) main query + date window (after:..before:.., drops time-irrelevant noise); too narrow, 0 hits -> retry once without the window
#     window = _gnews_date_window(question)
#     items = self._gnews_items(query + window) or self._gnews_items(query)
#
#     # 2) keyword re-search: full sentence missed / off-topic -> use a short entity/noun query (>=2 words, so a single generic word doesn't drag back a pile of off-topic news)
#     if not items or not _headlines_on_topic(items, question):
#         kwq = _keyword_query(question)
#         if kwq and len(kwq.split()) >= 2:
#             kw_items = self._gnews_items(kwq + window) or self._gnews_items(kwq)
#             if kw_items:
#                 items = kw_items + [it for it in items if it not in kw_items]
#
#     # 3) option-augmented re-search: still off-topic -> splice option keywords ("+missiles"/"+CEPI") into the query to surface answer articles the bare query missed
#     if not _headlines_on_topic(items, question):
#         opt_terms = _option_query_terms(question)
#         if opt_terms:
#             aug = (_strip_body_details(query) + " " + opt_terms).strip()
#             aug_items = self._gnews_items(aug + window) or self._gnews_items(aug)
#             if aug_items: items = aug_items + [...]
#
#     # 4) re-rank by closeness of pubDate to the question date -- a stale hit (e.g. a 2019 article) never outranks a current one
#     items = _rerank_by_recency(items, question)
#     headlines = [RetrievedDoc(text=t[:self.char_limit], source="google_news_rss") for t,_,_ in items[:top_k]]
#
#     # 5) fetch bodies (exact numbers / "who said it" live in the body): Guardian API first (~0.2s to get raw bodyText),
#     #    else browser/ddg as fallback. Filter each document by relevance to block captcha/Cloudflare pages and off-topic bodies
#     bodies = []
#     if self.fetch_bodies > 0 and self.body_mode != "off":
#         keywords = _question_keywords(question)
#         guardian = [d for d in self._guardian_bodies(query, question, self.fetch_bodies)
#                     if _relevance(d.text, keywords) >= _GUARDIAN_RELEVANCE_MIN]
#         if guardian:
#             bodies = guardian
#         else:                              # non-Guardian story -> take the broad web path, also filtered by relevance
#             fetched = self._fetch_bodies_via_browser([lnk for _,lnk,_ in items], ...) or ...
#             bodies = [d for d in fetched if _relevance(d.text, keywords) >= _GUARDIAN_RELEVANCE_MIN] or fetched
#
#     docs = bodies + headlines                # bodies first (richer), headlines after
#     return docs or self._ddg_search(query)   # all empty (gnews down) -> DDG fallback, else route to Wikipedia
# ```
#
# Each fetched body is then trimmed by `_focus_body()` around the question keywords to a budget length (keeping the answer sentence inside the window) before being handed to the prompt builder for grounding. Section 8 below has the **RAG vs no-RAG ablation**, confirming retrieval is a net gain (the model's priors are often wrong).

# %% [markdown]
# ## 5 · ▶ Play 10 live rounds  (each its own logged run)
#
# Plays the `TARGET` game `NUM_ROUNDS` times. Each round writes its own run dir `{target}_r{NN}` (so no
# round overwrites another — the LiveRunner truncates *within* a run_id). One round failing (a rate-limit, a
# network blip) is caught and logged as a gap — the loop carries on.

# %%
import time
from evaluation.runner import run_session

LOG_ROOT = os.path.join(REPO_ROOT, 'experiments', 'runs')
round_runs = []   # [(round_no, run_path-or-None)]

for r in range(1, NUM_ROUNDS + 1):
    config.run_id = f'{TARGET}_r{r:02d}'
    print(f'\n===== ▶ ROUND {r}/{NUM_ROUNDS}  (run_id={config.run_id}) =====')
    try:
        path = run_session(pipeline, config, game_client=game_client, log_root=LOG_ROOT)
        round_runs.append((r, path))
        print('   round log:', path)
    except Exception as e:
        round_runs.append((r, None))
        print(f'   ⚠️ round {r} FAILED ({type(e).__name__}: {e}) -- logged as a gap, the loop continues.')
    if r < NUM_ROUNDS:
        time.sleep(PAUSE_S)   # polite gap between live games.

print('\nAll rounds done. Logged runs:', [p for _r, p in round_runs if p])
# Out:
# ===== ▶ ROUND 1/10  (run_id=science_r01) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=5960 lvl=0 reached=0 -> D | correct=False | timed_out=False | latency=4.4s (left was 29.915732)
#    round log: /content/NLP/experiments/runs/science_r01
#
# ===== ▶ ROUND 2/10  (run_id=science_r02) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=5386 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.3s (left was 29.915632)
# [2] qid=4645 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.6s (left was 29.91476)
# [3] qid=4910 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.6s (left was 29.915443)
# [4] qid=1694 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.6s (left was 29.914191)
# [5] qid=5848 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.6s (left was 29.914061)
# [6] qid=5775 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=2.9s (left was 29.915543)
# [7] qid=3278 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.4s (left was 29.914815)
# [8] qid=4038 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=3.5s (left was 29.906031)
# [9] qid=4562 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=1.8s (left was 29.91472)
# [10] qid=4850 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=3.4s (left was 29.915151)
# [11] qid=5244 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=2.8s (left was 29.915178)
# [12] qid=1886 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=4.2s (left was 29.91531)
# [13] qid=1780 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=4.3s (left was 29.915338)
# [14] qid=1505 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.9s (left was 29.915632)
# [15] qid=1393 lvl=0 reached=14 -> D | correct=False | timed_out=False | latency=4.9s (left was 29.916237)
#    round log: /content/NLP/experiments/runs/science_r02
#
# ===== ▶ ROUND 3/10  (run_id=science_r03) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=3576 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=4.1s (left was 29.915784)
# [2] qid=1432 lvl=0 reached=1 -> B | correct=False | timed_out=False | latency=2.7s (left was 29.914834)
#    round log: /content/NLP/experiments/runs/science_r03
#
# ===== ▶ ROUND 4/10  (run_id=science_r04) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=4677 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.1s (left was 29.911234)
# [2] qid=4478 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.2s (left was 29.91529)
# [3] qid=3636 lvl=0 reached=2 -> C | correct=False | timed_out=False | latency=3.1s (left was 29.899153)
#    round log: /content/NLP/experiments/runs/science_r04
#
# ===== ▶ ROUND 5/10  (run_id=science_r05) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=5982 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.7s (left was 29.915803)
# [2] qid=5689 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=4.0s (left was 29.915331)
# [3] qid=1352 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=2.5s (left was 29.914338)
# [4] qid=5343 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=4.7s (left was 29.914399)
# [5] qid=5956 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.3s (left was 29.915156)
# [6] qid=3944 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=1.8s (left was 29.915425)
# [7] qid=5062 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=3.8s (left was 29.915358)
# [8] qid=2662 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.7s (left was 29.915205)
# [9] qid=5049 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.3s (left was 29.915036)
# [10] qid=1345 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=2.7s (left was 29.915648)
# [11] qid=6167 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=3.2s (left was 29.915393)
# [12] qid=1736 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.6s (left was 29.915877)
# [13] qid=2577 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=4.2s (left was 29.916358)
# [14] qid=2449 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=1.7s (left was 29.915639)
# [15] qid=2740 lvl=0 reached=15 -> C | correct=True | timed_out=False | latency=3.8s (left was 29.916042)
#    round log: /content/NLP/experiments/runs/science_r05
#
# ===== ▶ ROUND 6/10  (run_id=science_r06) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=6122 lvl=0 reached=0 -> D | correct=False | timed_out=False | latency=3.5s (left was 29.915667)
#    round log: /content/NLP/experiments/runs/science_r06
#
# ===== ▶ ROUND 7/10  (run_id=science_r07) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=4648 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=2.2s (left was 29.915656)
# [2] qid=3806 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=4.2s (left was 29.915078)
# [3] qid=5464 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=2.8s (left was 29.914969)
# [4] qid=3090 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=3.3s (left was 29.914378)
# [5] qid=4895 lvl=0 reached=4 -> B | correct=False | timed_out=False | latency=3.2s (left was 29.915059)
#    round log: /content/NLP/experiments/runs/science_r07
#
# ===== ▶ ROUND 8/10  (run_id=science_r08) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=2877 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=3.0s (left was 29.916113)
# [2] qid=5769 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.1s (left was 29.915119)
# [3] qid=3284 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=4.1s (left was 29.914273)
# [4] qid=3182 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=4.9s (left was 29.915304)
# [5] qid=5706 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.2s (left was 29.91464)
# [6] qid=4100 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=4.1s (left was 29.915764)
# [7] qid=3436 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.6s (left was 29.914923)
# [8] qid=3180 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.3s (left was 29.906787)
# [9] qid=5876 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=2.8s (left was 29.914506)
# [10] qid=5730 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.4s (left was 29.914663)
# [11] qid=3704 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=2.2s (left was 29.914218)
# [12] qid=2449 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=2.4s (left was 29.915988)
# [13] qid=2306 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.6s (left was 29.915679)
# [14] qid=2157 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=4.2s (left was 29.915929)
# [15] qid=2090 lvl=0 reached=15 -> B | correct=True | timed_out=False | latency=3.9s (left was 29.916779)
#    round log: /content/NLP/experiments/runs/science_r08
#
# ===== ▶ ROUND 9/10  (run_id=science_r09) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=6526 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.0s (left was 29.915004)
# [2] qid=5954 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.3s (left was 29.915507)
# [3] qid=4820 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.7s (left was 29.914604)
# [4] qid=3488 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.6s (left was 29.913913)
# [5] qid=4028 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.3s (left was 29.915197)
# [6] qid=5529 lvl=0 reached=None -> C | correct=True | timed_out=False | latency=2.8s (left was 29.915488)
# [7] qid=3073 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=3.9s (left was 29.915007)
# [8] qid=3270 lvl=0 reached=7 -> D | correct=False | timed_out=False | latency=2.7s (left was 29.914748)
#    round log: /content/NLP/experiments/runs/science_r09
#
# ===== ▶ ROUND 10/10  (run_id=science_r10) =====
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# [1] qid=1653 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.8s (left was 29.915218)
# [2] qid=1385 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.9s (left was 29.9153)
# [3] qid=2216 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=4.8s (left was 29.915285)
# [4] qid=3540 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=4.1s (left was 29.914118)
# [5] qid=5537 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=4.1s (left was 29.914935)
# [6] qid=2276 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=2.0s (left was 29.915219)
# [7] qid=1969 lvl=0 reached=None -> D | correct=True | timed_out=False | latency=3.3s (left was 29.910174)
# [8] qid=5475 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=2.6s (left was 29.915121)
# [9] qid=4833 lvl=0 reached=None -> A | correct=True | timed_out=False | latency=3.6s (left was 29.915403)
# [10] qid=3295 lvl=0 reached=None -> B | correct=True | timed_out=False | latency=3.6s (left was 29.915551)
# [11] qid=4829 lvl=0 reached=10 -> B | correct=False | timed_out=False | latency=5.9s (left was 29.915476)
#    round log: /content/NLP/experiments/runs/science_r10
#
# All rounds done. Logged runs: ['/content/NLP/experiments/runs/science_r01', '/content/NLP/experiments/runs/science_r02', '/content/NLP/experiments/runs/science_r03', '/content/NLP/experiments/runs/science_r04', '/content/NLP/experiments/runs/science_r05', '/content/NLP/experiments/runs/science_r06', '/content/NLP/experiments/runs/science_r07', '/content/NLP/experiments/runs/science_r08', '/content/NLP/experiments/runs/science_r09', '/content/NLP/experiments/runs/science_r10']

# %% [markdown]
# ## 6 · Analysis — per-round scores + every wrong question (with diagnostics)
#
# Aggregates all rounds and **saves** the consolidated records to `experiments/{TARGET}_test/` so they ride
# back to the repo. Three artifacts: a per-round summary, every question, and the wrong questions alone.
# - **News**: wrong questions carry the retrieved evidence text (retrieval-miss vs grounding-miss diagnosis)
#   and a retrieval source mix.
# - **Math**: wrong questions carry the reasoning chain (`raw_output`), which routing strategy fired
#   (`prompt_strategy`), and the output token count — so you can see truncation at the 300-token cap.

# %%
import json, collections
from pathlib import Path
import pandas as pd

OUT_DIR = Path(REPO_ROOT) / 'experiments' / f'{TARGET}_test'
OUT_DIR.mkdir(parents=True, exist_ok=True)

def _read_round(path):
    """One round's records.jsonl -> list of dict rows ([] if missing/empty)."""
    if not path:
        return []
    p = Path(path) / 'records.jsonl'
    if not p.exists():
        return []
    return [json.loads(l) for l in p.read_text(encoding='utf-8').splitlines() if l.strip()]

def _sources(row):
    """The retrieval SOURCE mix for a row, from retrieved_snippets ('[theguardian.com#..] ' prefix)."""
    out = collections.Counter()
    for s in (row.get('retrieved_snippets') or []):
        if isinstance(s, str) and s.startswith('['):
            out[s[1:].split('#', 1)[0].split(']', 1)[0]] += 1
    return dict(out)

# --- Gather every round ---
summary_rows, all_q, wrong_q = [], [], []
for r, path in round_runs:
    rows = _read_round(path)
    graded = [x for x in rows if x.get('correct') is not None]
    n_correct = sum(1 for x in graded if x.get('correct') is True)
    reached = [x.get('reached_level') for x in rows if x.get('reached_level') is not None]
    summary_rows.append({
        'round': r,
        'answered': len(rows),
        'correct': n_correct,
        'graded': len(graded),
        'accuracy': (n_correct / len(graded)) if graded else float('nan'),
        'reached_level': max(reached) if reached else None,
    })
    for x in rows:
        rec = {'round': r, **x, 'sources': _sources(x)}
        all_q.append(rec)
        if x.get('correct') is False:
            wrong_q.append(rec)

# --- Per-round summary + overall ---
summary = pd.DataFrame(summary_rows)
print(f'PER-ROUND SUMMARY ({TARGET})')
print(summary.to_string(index=False))
tot_c = int(summary['correct'].sum()); tot_g = int(summary['graded'].sum())
lv = [s['reached_level'] for s in summary_rows if s['reached_level'] is not None]
print(f"\nOVERALL: {tot_c}/{tot_g} graded = {tot_c / tot_g:.1%}" if tot_g else '\nOVERALL: no graded answers')
if lv:
    print(f"reached_level over {len(lv)} rounds: min={min(lv)} max={max(lv)} mean={sum(lv)/len(lv):.1f} | {sorted(lv, reverse=True)}")

if RETRIEVAL_TARGET:
    # --- Retrieval source mix across ALL questions (did the gate route to the browser? did docs land?) ---
    src_total = collections.Counter()
    for x in all_q:
        src_total.update(x['sources'])
    print('\nRETRIEVAL SOURCE MIX (doc count across all', len(all_q), 'questions):', dict(src_total))
    fired = sum(1 for x in all_q if x.get('retrieval_used'))
    print(f"retrieval fired on {fired}/{len(all_q)} questions")
else:  # math -- which routing strategy fired, and how close to the 300-token cap the chains ran.
    strat_mix = collections.Counter(x.get('prompt_strategy') or '?' for x in all_q)
    print('\nROUTING STRATEGY MIX (across all', len(all_q), 'questions):', dict(strat_mix))
    toks = [x.get('tokens_out', 0) for x in all_q if x.get('tokens_out')]
    if toks:
        capped = sum(1 for t in toks if t >= 300)
        print(f"tokens_out: min={min(toks)} max={max(toks)} mean={sum(toks)/len(toks):.0f}"
              f" | hit the 300 cap on {capped}/{len(toks)} questions (likely truncated before 'Answer:')")
# Out:
# PER-ROUND SUMMARY (science)
#  round  answered  correct  graded  accuracy  reached_level
#      1         1        0       1  0.000000              0
#      2        15       14      15  0.933333             14
#      3         2        1       2  0.500000              1
#      4         3        2       3  0.666667              2
#      5        15       15      15  1.000000             15
#      6         1        0       1  0.000000              0
#      7         5        4       5  0.800000              4
#      8        15       15      15  1.000000             15
#      9         8        7       8  0.875000              7
#     10        11       10      11  0.909091             10
#
# OVERALL: 68/76 graded = 89.5%
# reached_level over 10 rounds: min=0 max=15 mean=6.8 | [15, 15, 14, 10, 7, 4, 2, 1, 0, 0]
#
# ROUTING STRATEGY MIX (across all 76 questions): {'cot_v2': 75, 'structured_enumeration_cot': 1}
# tokens_out: min=6 max=57 mean=25 | hit the 300 cap on 0/76 questions (likely truncated before 'Answer:')

# %%
# --- Every WRONG question, with the right diagnostics for the target ---
#   News / Entertainment: the retrieved EVIDENCE (retrieval-miss vs grounding-miss check).
#   Math: the reasoning chain (raw_output), the routing strategy that fired, and tokens_out (cap = 300).
print(f"{'=' * 78}\nEVERY WRONG QUESTION  ({len(wrong_q)} across {NUM_ROUNDS} rounds)\n{'=' * 78}")
for x in wrong_q:
    opts = x.get('options') or {}
    pick = x.get('predicted_answer')
    if RETRIEVAL_TARGET:
        print(f"\n[round {x['round']}] qid={x['qid']} reached_level={x.get('reached_level')} "
              f"lat={x.get('latency_s', 0):.1f}s sources={x['sources']}")
    else:
        toks = x.get('tokens_out', 0)
        print(f"\n[round {x['round']}] qid={x['qid']} level={x.get('level')} reached_level={x.get('reached_level')} "
              f"lat={x.get('latency_s', 0):.1f}s strategy={x.get('prompt_strategy')} "
              f"tokens_out={toks}{'  <-- HIT 300 CAP (truncated?)' if toks and toks >= 300 else ''}")
    print(f"Q: {x['question_text']}")
    for k, v in opts.items():
        print(f"   {k}. {v}" + ('  <-- our pick (WRONG)' if k == pick else ''))
    if RETRIEVAL_TARGET:
        snips = x.get('retrieved_snippets') or []
        if snips:
            print('   -- retrieved evidence --')
            for s in snips:
                print(f"      {str(s)[:500]}")
        else:
            print('   (no retrieved evidence logged)')
    else:  # math -- the model's reasoning chain (truncation / wrong set-up shows here).
        raw = (x.get('raw_output') or '').strip()
        print('   -- reasoning chain --')
        print('      ' + (raw[:900].replace('\n', '\n      ') if raw else '(empty)'))

# --- SAVE the consolidated artifacts (ride back to the repo via experiments/) ---
summary.to_csv(OUT_DIR / 'summary.csv', index=False)
with open(OUT_DIR / 'all_questions.jsonl', 'w', encoding='utf-8') as f:
    for x in all_q:
        f.write(json.dumps(x, ensure_ascii=False) + '\n')
with open(OUT_DIR / 'wrong_questions.jsonl', 'w', encoding='utf-8') as f:
    for x in wrong_q:
        f.write(json.dumps(x, ensure_ascii=False) + '\n')
print(f"\nSaved -> {OUT_DIR}/  (summary.csv, all_questions.jsonl [{len(all_q)}], wrong_questions.jsonl [{len(wrong_q)}])")
# Out:
# ==============================================================================
# EVERY WRONG QUESTION  (8 across 10 rounds)
# ==============================================================================
#
# [round 1] qid=5960 level=0 reached_level=0 lat=4.4s strategy=cot_v2 tokens_out=36
# Q: Salt water, plastic, and helium are all made of
#    A. compounds.
#    B. atoms.
#    C. electrons.
#    D. mixtures.  <-- our pick (WRONG)
#    -- reasoning chain --
#       1. Salt water is a mixture.
#       2. Plastic is made of molecules, not pure elements.
#       3. Helium is an element, not a compound.
#
#       Answer: D
#
# [round 2] qid=1393 level=0 reached_level=14 lat=4.9s strategy=cot_v2 tokens_out=36
# Q: Which of the following statements best explains the relationship between superfluidity and Bose–Einstein condensation (BEC)?
#    A. Superfluidity and Bose–Einstein condensation are independent phenomena, but they can co-occur in certain systems.
#    B. Bose–Einstein condensation is a prerequisite for superfluidity in all systems.
#    C. Superfluidity always occurs when a system undergoes Bose–Einstein condensation.
#    D. Bose–Einstein condensation is a special case of superfluidity, but not all superfluids are Bose–Einstein condensates.  <-- our pick (WRONG)
#    -- reasoning chain --
#       1. Superfluidity requires BEC for liquid helium-4.
#       2. Not all superfluids are BECs, e.g., He-3.
#
#       Answer: D
#
# [round 3] qid=1432 level=0 reached_level=1 lat=2.7s strategy=cot_v2 tokens_out=18
# Q: Which of the following best describes the fundamental principle of the Peltier effect?
#    A. Heat is generated when a voltage is applied to a thermocouple, causing a temperature difference.
#    B. Heat is generated by Joule heating when a current passes through a conductor.  <-- our pick (WRONG)
#    C. A thermocouple creates a voltage difference when there is a temperature difference across it.
#    D. A temperature difference causes a voltage to be generated, which can be used to measure temperature.
#    -- reasoning chain --
#       1. Peltier effect involves heat generation by current.
#       2. Answer: B
#
# [round 4] qid=3636 level=0 reached_level=2 lat=3.1s strategy=cot_v2 tokens_out=21
# Q: What is one difference between birds and reptiles?
#    A. Reptiles are cold-blooded and birds are not.
#    B. Reptiles are meat-eaters and birds are not.
#    C. Birds lay eggs and reptiles do not.  <-- our pick (WRONG)
#    D. Birds breathe oxygen and reptiles do not.
#    -- reasoning chain --
#       1. Birds lay eggs.
#       2. Reptiles also lay eggs.
#       3. Answer: C
#
# [round 6] qid=6122 level=0 reached_level=0 lat=3.5s strategy=cot_v2 tokens_out=28
# Q: Why do some animals hibernate in the winter?
#    A. to adapt to environmental changes
#    B. to avoid predators
#    C. to attract a mate
#    D. to find food for their young  <-- our pick (WRONG)
#    -- reasoning chain --
#       1. Hibernation reduces metabolic rate to conserve energy.
#       2. Winter has limited food availability.
#       3. D
#
#       Answer: D
#
# [round 7] qid=4895 level=0 reached_level=4 lat=3.2s strategy=cot_v2 tokens_out=23
# Q: Which type of energy conversion occurs in a flashlight?
#    A. mechanical to chemical
#    B. electrical to chemical  <-- our pick (WRONG)
#    C. mechanical to light
#    D. chemical to light
#    -- reasoning chain --
#       1. Flashlight uses battery for power.
#       2. Battery converts chemical energy to electrical energy.
#       Answer: B
#
# [round 9] qid=3270 level=0 reached_level=7 lat=2.7s strategy=cot_v2 tokens_out=19
# Q: The students observed a large crack found in a boulder with a tree growing out of it. Which process were the students observing?
#    A. weathering
#    B. oxidizing
#    C. deposition
#    D. decomposition  <-- our pick (WRONG)
#    -- reasoning chain --
#       1. Tree growing suggests biological activity.
#       2. Biological activity indicates decomposition. Answer: D
#
# [round 10] qid=4829 level=0 reached_level=10 lat=5.9s strategy=cot_v2 tokens_out=57
# Q: A man ran on a treadmill for 1,800 seconds. At the end of his run, the treadmill indicated his energy output as 240,000 J. What average power did he generate?
#    A. 7 W
#    B. 66 W  <-- our pick (WRONG)
#    C. 666 W
#    D. 133 W
#    -- reasoning chain --
#       1,800 seconds = 1800 / 240,000 = 0.125 W * 1000 = 125 W / 2 = 66.67 W
#
#       Answer: B
#
# Saved -> /content/NLP/experiments/science_test/  (summary.csv, all_questions.jsonl [76], wrong_questions.jsonl [8])

# %% [markdown]
# ## 8 · RAG vs no-RAG ablation — retrieval targets only — do questions answer better WITHOUT retrieval?
#
# **Runs only for retrieval targets (`TARGET` in `entertainment` / `news`)** — Maths uses no retrieval, so there is nothing to ablate, and this cell is skipped there.
#
# Some News questions are really **knowledge/historical** ("which US president visited China in 2008..") —
# the model may know the answer from its **own training**, and an off-topic retrieved article can *mislead*
# it (grounding on junk). This re-answers the SAME questions **with** retrieval and **without**, side by
# side, so we can see where RAG helps vs hurts. Annotate `KNOWN_GOLD` for questions you can verify by hand
# to get a score (live games hide the gold).

# %%
if not RETRIEVAL_TARGET:
    print(f"RAG-vs-noRAG ablation needs a retriever (Maths uses none) -- skipping for TARGET = {TARGET}.")
else:
    import json
    from schemas import Question, QuestionType
    from agent.pipeline import QAPipeline
    from prompting.builder import PromptBuilder
    from classify.classifier import QuestionClassifier
    from tools import default_tools

    # Twin of THIS target's RAG pipeline, but retriever=None -> pure parametric knowledge (no RAG).
    _strategy = 'few_shot_entertainment' if TARGET == 'entertainment' else config.prompt_strategy
    pipeline_norag = QAPipeline(
        engine=engine,
        prompt_builder=PromptBuilder(strategy=_strategy),
        classifier=QuestionClassifier(),
        retriever=None,                 # <- the only difference from the RAG `pipeline`.
        tools=default_tools(),
        latency_budget_s=config.latency_budget_s,
    )

    # Questions to probe. Default: the wrong questions THIS News run logged. Point SRC elsewhere to test others.
    SRC = os.path.join(REPO_ROOT, 'experiments', f'{TARGET}_test', 'wrong_questions.jsonl')
    rows = [json.loads(l) for l in open(SRC, encoding='utf-8') if l.strip()]

    # Known gold BY TEXT substring (resolved to the option letter at runtime -> robust to option shuffling).
    # Fill in the ones you can verify; un-annotated rows are still printed for eyeballing.
    # NOTE: the entries below are News examples -- for Entertainment, replace them with your own verified golds.
    KNOWN_GOLD = {
        '10851': 'George W. Bush',     # Bush attended a Beijing church service, 2008 Olympics
        '10659': 'CEPI',               # Coalition for Epidemic Preparedness Innovations
        '12017': 'Cannes',             # Cannes Film Festival opens ~May 12
        '10645': '161',                # Pentagon released ~16x declassified UFO files
        '10747': '1.5 million',        # Labour's housing pledge
    }

    def _build_q(r):
        try: qt = QuestionType(r.get('qtype', 'mcq'))
        except Exception: qt = QuestionType.MCQ
        return Question(qid=r['qid'], text=r['question_text'], options=r.get('options') or {},
                        qtype=qt, level=r.get('level'), topic=r.get('topic'), language=r.get('language'))

    def _gold_letter(r):
        sub = KNOWN_GOLD.get(str(r['qid']))
        if not sub:
            return None
        for k, v in (r.get('options') or {}).items():
            if sub.lower() in str(v).lower():
                return k
        return None

    print(f"{'qid':>7} | RAG | noRAG | gold | verdict")
    print('-' * 70)
    rag_ok = norag_ok = scored = 0
    for r in rows:
        q = _build_q(r)
        a_rag = pipeline.answer(q).answer          # WITH live retrieval
        a_no  = pipeline_norag.answer(q).answer    # parametric knowledge only
        gold = _gold_letter(r)
        verdict = ''
        if gold:
            scored += 1
            rag_ok   += (a_rag == gold)
            norag_ok += (a_no  == gold)
            verdict = f"RAG {'OK' if a_rag==gold else 'X'} | noRAG {'OK' if a_no==gold else 'X'}"
        print(f"{r['qid']:>7} |  {a_rag}   |  {a_no}    |  {gold or '-'}   | {verdict}")
        print(f"          Q: {r['question_text'][:82]}")

    if scored:
        print(f"\nON {scored} ANNOTATED-GOLD QUESTIONS:   RAG {rag_ok}/{scored}    no-RAG {norag_ok}/{scored}")
    print("\n(Eyeball RAG vs noRAG on the un-annotated rows; add to KNOWN_GOLD to score more.)")
# Out:
# RAG-vs-noRAG ablation needs a retriever (Maths uses none) -- skipping for TARGET = science.

# %% [markdown]
# ## 9 · Solver self-test (Maths-only) — confirm the deterministic solver is wired & firing
#
# **Runs only when `TARGET == 'math'`** — the solver is a Maths component; skipped for entertainment / news.
#
# Doesn't depend on luck-of-the-draw. **Part 1** calls `solve_maths()` directly (pure Python, no model). **Part 2** runs the same questions through a Maths pipeline with `solver=solve_maths` — if `tool_used=math_solver` and `tokens_out=0`, the LLM was short-circuited (the program answered, not the model).

# %%
# Maths-only: the deterministic solver is a Maths component -- skip it on other targets so an
# entertainment / news run never executes the Maths self-test.
if TARGET != 'math':
    print(f"Solver self-test is Maths-only -- skipping for TARGET = {TARGET}.")
else:
    # ============================================================================
    # Solver self-test -- confirm the deterministic solver is WIRED and FIRING (no luck-of-the-draw).
    # Part 1: call solve_maths() directly (pure Python, NO model) -> proves the program computes the answer.
    # Part 2: run the SAME questions through a Maths pipeline with solver=solve_maths -> proves the LLM is
    #         SHORT-CIRCUITED (tool_used='math_solver', tokens_out=0 -> the model never generated anything).
    # Run this BEFORE the model-comparison cell below (that one frees `engine`).
    # ============================================================================
    from schemas import Question, QuestionType
    from tools import solve_maths
    from prompting.builder import RoutingPromptBuilder
    from classify.reasoning_router import MATHS_LIVE_POLICY, MATHS_LIVE_FALLBACK
    from classify.classifier import QuestionClassifier
    from agent.pipeline import QAPipeline

    _TESTS = [
        ('6886', 'Find all zeros in the indicated finite field of the given polynomial x^5 + 3x^3 + x^2 + 2x in Z_5',
         {'A': '0,4', 'B': '0,1', 'C': '0', 'D': '1'}, 'A'),
        ('6722', 'Find the characteristic of the ring Z_3 x Z_3', {'A': '3', 'B': '30', 'C': '12', 'D': '0'}, 'A'),
        ('6962', 'Two numbers added together are 19. Their product is 70. What are the two numbers?',
         {'A': '7, 10', 'B': '4, 15', 'C': '5, 14', 'D': '3, 16'}, 'C'),
        ('6809', 'What is the greatest common divisor of $2^{1001}-1$ and $2^{1012}-1$?',
         {'A': '2047', 'B': '2049', 'C': '1', 'D': '2048'}, 'A'),
    ]

    print("PART 1 -- solve_maths() directly (pure Python, no model):")
    for qid, text, opts, gold in _TESTS:
        q = Question(qid=qid, text=text, options=opts, qtype=QuestionType.MCQ)
        r = solve_maths(q)
        ok = '✅' if (r and r[0] == gold) else '❌'
        print(f"  {qid}: {r}  expect={gold}  {ok}")

    print("\nPART 2 -- through a Maths pipeline (solver=solve_maths) -> the model should be SKIPPED:")
    _mp = QAPipeline(engine=engine,
                     prompt_builder=RoutingPromptBuilder(policy=MATHS_LIVE_POLICY, fallback_strategy=MATHS_LIVE_FALLBACK),
                     classifier=QuestionClassifier(), retriever=None, tools=None, solver=solve_maths,
                     latency_budget_s=config.latency_budget_s, max_new_tokens=450)
    print(f"{'qid':>6} | tool_used   | tokens_out | answer | expect | ok")
    print('-' * 62)
    for qid, text, opts, gold in _TESTS:
        p = _mp.answer(Question(qid=qid, text=text, options=opts, qtype=QuestionType.MCQ))
        ok = '✅' if p.answer == gold else '❌'
        print(f"{qid:>6} | {str(p.tool_used):11} | {p.tokens_out:>10} | {p.answer:^6} | {gold:^6} | {ok}")
    print("\nIf tool_used=math_solver AND tokens_out=0 -> the solver is LIVE and the model was NOT used on those.")
    print("If tool_used=None here, the solver is NOT wired in this notebook's pipeline (re-pull / re-run cell 10).")
# Out:
# Solver self-test is Maths-only -- skipping for TARGET = science.

# %% [markdown]
# ## 10 · Model comparison (Maths-only) — base 7B vs a math-specialised open model
#
# **Runs only when `TARGET == 'math'`.** ⚠️ It loads a SECOND model and FREES `engine` — never run it on an entertainment / news session (it would tear down the live pipeline).
#
# Answers the assignment's *"are certain models better at certain topics?"*. Same Maths questions through both models' **pure-LLM** pipeline (solver OFF — measures the *model*), scored vs hand-verified gold, with flips and >25s flags.
#
# > Open-weight + local only (no API). On a **T4** the two 7B-4bit models can't co-reside, so the base model is freed before the math model loads — **re-run the *Load + warm up the model* cell afterwards** to restore `engine`. ⚠️ This cell must be RUN on Colab (loads a 2nd model, ~5 min); it does nothing if just pulled.

# %%
# Maths-only AND destructive (loads a 2nd model, FREES `engine`). Guard hard: on any non-Maths
# target skip entirely, so an entertainment / news run never tears down its own live engine.
if TARGET != 'math':
    print(f"Model comparison is Maths-only (and frees `engine`) -- skipping for TARGET = {TARGET}.")
else:
    # ============================================================================
    # 9 · MODEL COMPARISON (Maths) -- base Qwen2.5-7B vs a math-specialised open model.
    # Assignment investigation question: "are certain models better at certain topics?"
    # Same Maths questions through BOTH models' PURE-LLM pipeline (solver OFF -> we measure the
    # MODEL, not the deterministic short-circuit), scored vs hand-verified gold, flags flips + >25s.
    # Rules: open-weight, local only (no API). T4 NOTE: two 7B-4bit can't co-reside, so we FREE the
    # base model before loading the math one -> re-run the "Load + warm up the model" cell to restore it.
    # ============================================================================
    import time, json, gc, os
    import torch
    from schemas import Question, QuestionType
    from prompting.builder import RoutingPromptBuilder
    from classify.reasoning_router import MATHS_LIVE_POLICY, MATHS_LIVE_FALLBACK
    from classify.classifier import QuestionClassifier
    from agent.pipeline import QAPipeline
    from inference.engine import TransformersEngine

    MATH_MODEL = 'Qwen/Qwen2.5-Math-7B-Instruct'   # the challenger (open-weight only); swap to try others.
    FREE_A_BEFORE_B = True                          # T4: free the base model before loading the math one.

    # --- question set: this run's saved Maths questions if present, else a small embedded fallback ---
    rows, SRC = [], None
    for cand in ('all_questions.jsonl', 'wrong_questions.jsonl'):
        p = os.path.join(REPO_ROOT, 'experiments', 'math_test', cand)
        if os.path.exists(p):
            SRC = p
            rows = [json.loads(l) for l in open(p, encoding='utf-8') if l.strip()]
            break
    if not rows:   # fallback so the cell always runs (knowledge-heavy: where a math model should help)
        SRC = 'embedded fallback'
        rows = [
            {'qid': '6919', 'question_text': 'Statement 1 | Q is an extension field of Z_2. Statement 2 | Every non-constant polynomial over a field has a zero in some extension field.', 'options': {'A': 'True, False', 'B': 'False, False', 'C': 'True, True', 'D': 'False, True'}},
            {'qid': '6713', 'question_text': 'Statement 1 | If H is a subgroup of a group G and a belongs to G, then aH = Ha. Statement 2 | If H is normal of G and a belongs to G, then ah = ha for all h in H.', 'options': {'A': 'True, False', 'B': 'True, True', 'C': 'False, False', 'D': 'False, True'}},
            {'qid': '6910', 'question_text': 'Statement 1 | If T: V -> W is a linear transformation and dim(V) < dim(W) < 1, then T must be injective. Statement 2 | Let dim(V) = n and suppose that T: V -> V is linear. If T is injective, then it is a bijection.', 'options': {'A': 'False, False', 'B': 'False, True', 'C': 'True, True', 'D': 'True, False'}},
            {'qid': '6767', 'question_text': 'Find the order of the factor group (Z_4 x Z_12)/(<2> x <2>)', 'options': {'A': '3', 'B': '4', 'C': '12', 'D': '2'}},
            {'qid': '6886', 'question_text': 'Find all zeros in the indicated finite field of the given polynomial with coefficients in that field. x^5 + 3x^3 + x^2 + 2x in Z_5', 'options': {'A': '0,4', 'B': '0,1', 'C': '0', 'D': '1'}},
        ]
    rows = list({r['qid']: r for r in rows}.values())   # dedupe by qid
    print(f"comparison set: {len(rows)} Maths questions  (source: {SRC})")

    # --- hand-verified gold BY TEXT SUBSTRING (unambiguous within each option set). Add more freely. ---
    KNOWN_GOLD = {
        '6886': '0,4', '6809': '2047', '6962': '5, 14', '6728': '37', '6932': '8', '7021': '0', '6841': '46',
        '6899': 'Friday', '6817': '70', '6767': '4', '6781': '3', '6671': '24', '6688': '15',
        '6919': 'False, True', '6713': 'False, False', '6910': 'True, True', '6912': 'True, True',
        '6894': 'False, False', '6696': 'False, True',
    }

    def _bq(r):
        try: qt = QuestionType(r.get('qtype', 'mcq'))
        except Exception: qt = QuestionType.MCQ
        return Question(qid=r['qid'], text=r['question_text'], options=r.get('options') or {}, qtype=qt,
                        level=r.get('level'), topic=r.get('topic'), language=r.get('language'))

    def _gold(r):
        sub = KNOWN_GOLD.get(str(r['qid']))
        if not sub: return None
        hits = [k for k, v in (r.get('options') or {}).items() if sub.lower() in str(v).lower()]
        return hits[0] if len(hits) == 1 else None

    def _make_pipe(eng):   # PURE-LLM Maths pipeline (solver OFF) -> measures the MODEL itself.
        return QAPipeline(engine=eng, prompt_builder=RoutingPromptBuilder(policy=MATHS_LIVE_POLICY, fallback_strategy=MATHS_LIVE_FALLBACK),
                          classifier=QuestionClassifier(), retriever=None, tools=None, solver=None,
                          latency_budget_s=config.latency_budget_s, max_new_tokens=450)

    def _run(eng, label):
        pipe, out = _make_pipe(eng), {}
        for r in rows:
            t0 = time.perf_counter(); pred = pipe.answer(_bq(r)); out[r['qid']] = (pred.answer, time.perf_counter() - t0)
        print(f"  {label}: {len(out)} answered"); return out

    print(f"\n[A] base model: {config.model.name}")
    resA = _run(engine, 'A')

    if FREE_A_BEFORE_B:
        del engine; gc.collect(); torch.cuda.empty_cache()
        print("   freed base model (re-run the model-load cell to restore `engine` afterwards).")

    print(f"\n[B] loading math model: {MATH_MODEL}")
    engine_math = TransformersEngine(model_name=MATH_MODEL, quantization=config.model.quantization, dtype=config.model.dtype)
    engine_math.warmup()
    resB = _run(engine_math, 'B')

    # --- compare ---
    print(f"\n{'qid':>7} | A | B | gold | note")
    print('-' * 64)
    a_ok = b_ok = scored = Bfix = Bbreak = 0; over = []
    for r in rows:
        q = r['qid']; (aA, latA), (aB, latB) = resA[q], resB[q]; g = _gold(r)
        if latA > 25: over.append((q, 'A', round(latA, 1)))
        if latB > 25: over.append((q, 'B', round(latB, 1)))
        note = ''
        if g:
            scored += 1; oa, ob = (aA == g), (aB == g); a_ok += oa; b_ok += ob
            if ob and not oa: Bfix += 1; note = 'B fixes A'
            elif oa and not ob: Bbreak += 1; note = 'B BREAKS A'
        print(f"{q:>7} | {aA} | {aB} | {g or '-'} | {note}{'  <-DIFF' if aA != aB else ''}")

    if scored:
        print(f"\nON {scored} GOLD-LABELLED:  base-A {a_ok}/{scored} ({a_ok/scored:.0%})   |   math-B {b_ok}/{scored} ({b_ok/scored:.0%})")
        print(f"   B fixes A: {Bfix}   |   B breaks A: {Bbreak}   (net {Bfix-Bbreak:+d})")
    print(f"latency >25s (wall risk): {over or 'none'}")
    print("\nNOTE: this measures the MODEL (solver OFF). Add qids to KNOWN_GOLD to score more.")
    print("To restore the 7B for other cells, RE-RUN the 'Load + warm up the model' cell.")
# Out:
# Model comparison is Maths-only (and frees `engine`) -- skipping for TARGET = science.
